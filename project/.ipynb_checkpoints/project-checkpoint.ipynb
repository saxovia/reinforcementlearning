# %% [markdown]
# <div class="alert alert-block alert-info">
#    <h2 align="center"> <center><b> Reinforcement Learning Project - Sanding Task </b></center></h2>
#
# <br>
# <center><font size="3">This notebook is part of the teaching materials for ELEC-E8125</font></center>
# <center><font size="3">Sep 4, 2024 - Nov 30, 2024</font></center>
# <center><font size="3">Aalto University</font></center>
# </div>
#
#
# <a id='TOC'></a>
#
# <div class="alert alert-block alert-success">
#
# # Table of contents
# * <a href='#1.'> 1. Learning Objectives</a>
# * <a href='#2.'> 2. Introduction </a>
# * <a href='#3.'> 3. Sanding Task </a>
# * <a href='#4.'> 4. Code Structure and Files </a>
# * <a href='#5.'> 5. Tasks </a>
# * <a href='#6.'> 6. Implementation requirements </a>
# * <a href='#7.'> 7. Evaluation / grading </a>
# * <a href='#8.'> 8. Start the project </a>
# * <a href='#9'> 9. Submission </a>
# * <a href='#10'> 10. Feedback  </a>
#
# <a href='#T1'><b>Student Task 1.</b> Implement the basic PPO or DDPG algorithm. Modify either 'ddpg_agent.py' or 'ppo_agent.py' in the folder 'algos'. Run the algorithm in the easy and medium sanding environments. Report the results, that is, training plots and test performances. (30 points)</a>
#
# <a href='#T2'><b>Student Task 2.</b> Extend DDPG/PPO to improve the performance based on the hints in Section 5. Note the instructions on the extensions in Section 5. You can should use either the file 'ddpg_extension.py' or 'ppo_extension.py' in folder 'algos'. Do the following: 1. The base algorithm's performance must be improved such that the agent succeeds in the moderate difficulty environment. 2. Follow the provided structure such that it can be tested with function 'test(agent)'. (40 points)</a>
#
# <a href='#Q1'><b>Student Question 1.</b> Answer the question regarding how you extended PPO/DDPG. (30 points) </a>
#
# <a href='#T3'><b>Student Task 3.</b> This task gives bonus points to the project works that get highest performance. The projects will be evaluated based on their performance in the difficult Task 3 environment and then ranked. The best performing project (100% ranked) will receive 20 bonus points, 95% ranked or above will get 10 bonus points. (+20 points) </a>
#
# **Total Points:** 100 (+20)

# %% [markdown]
# <div style="background-color:lightcoral; padding:10px; border-radius:5px">
#
# # <span style="color:white">0. Group Information (IMPORTANT)</span>
#
# ## <span style="color:white">Please read the instructions and fill in your group information</span>
#
# - This project work is intended to be completed in groups of 2 students, who will share the same grade. If you are looking for a project partner, please join the project channel on Zulip and introduce yourself.
#
# - However, it is also acceptable to complete the project individually.
#
# - **Only one student** from each group should submit the project.
#
# - Please provide the **NAME (First Name Last Name)**, **Aalto Student ID**, and **Aalto User Name** of each group member. For example:
#     - Member 0: Jane Doe, 123456, janed5
#
# </div>

# %% [markdown]
# <div style="background-color:lightcoral; padding:10px; border-radius:5px; margin-bottom: 10px">
#
# # <span style="color:white">### TODO: Fill in Your Group Information HERE</span>
#
# DOUBLE CLICK TO EDIT
# - **Member 1:**
#   - Name: Olívia Szász
#   - Aalto Student ID: 102565223
#   - Aalto User Name: szaszo1
#
# - **Member 2 (if applicable):**
#   - Name:
#   - Aalto Student ID:
#   - Aalto User Name:
#
# </div>

# %% [markdown]
# # 1. Learning Objectives <a id='1.'></a>
# In the project work, students move to a more independent working style compared with the exercises. In the exercises, instructions and template code for reinforcement learning algorithms were provided. However, in the project work the students are given **a new task** that they need to solve using reinforcement learning methods discussed during the course. The students need to decide which method they will use (either PPO or DDPG), extend the method, and explain why. Students may take advantage of code that they have already developed in the exercises or which was part of the exercises.

# %% [markdown]
# # 2. Introduction <a id='2.'></a>
#
# The goal of the project work is to optimize the behavior of a sanding robot using reinforcement learning such that the robot avoids already painted areas but sands areas that need sanding. We give now a general motivation and task description. [Section 3](#3.) provides a more detailed task definition.
#
# <center>
# <figure style="display: inline-block; text-align: center; margin: 10px;">
#   <img src="imgs/robot_sanding.png" width="width:40%"/>
# </figure>
# </center>
# <center>Figure 1: Illustration of a robot sanding a planar area. Image source: (https://www.youtube.com/watch?v=TG-3NZzoZiM)</center>
#
# The robot operates on a 2-D plane and should hit a set of "sanding areas" using the sanding tool equipped. At the same time the robot has to avoid specific "painted areas" which are also defined as part of the system state. The sanding areas and painted areas are defined as part of the state space. The robot gets a negative reward for hitting painted areas and a positive reward for sanding sanding areas.
#
# The idea is to optimize the behavior of the robot using reinforcement learning based on either the PPO or DDPG algorithm. You should extend PPO or DDPG such that you get higher performance in the more challenging versions of the sanding task.
#
# [Section 3](#3.) defines the sanding task. [Section 4](#4.) shows the structure of the provided file directory. [Section 5](#5.) discusses the **mandatory project requirements** and **possible extensions** to the basic PPO and DDPG algorithms. [Section 6](#6.) discusses the implementation requirements. [Section 7](#7.a) describes how the project is evaluated and graded. In [Section 8](#8.), you will add your implementation, perform the tasks and answer questions. [Section 9](#9.) is a preliminary check. In [Section 10](#10.), you can provide feedback on the project work.

# %% [markdown]
# # 3. Sanding Task <a id='3.'></a>
# The primary objective in this project is to optimize a sanding robot's behavior, aiming to maximize the expected cumulative reward $ J(\theta) = \mathbb{E}_{\pi_{\theta}}\left[ \sum_{t=0}^{\infty} \gamma^t r_t \right] $. The simulator for the sanding task is provided in the "sanding.py" Python file. This section defines the sanding task. Please, see below.
#
# ## 3.1. Markov Decision Process (MDP)
# - **Robot Characteristics**: The robot is visualized as a <span style="color:purple">purple</span> circle with a radius of 10, operating on a 2D plane. The x and y coordinates range from -50 to 50.
# - **Sanding & No-Sanding Areas**: There are sanding (<span style="color:green">green</span>) and no-sanding (<span style="color:red">red</span>) areas, each with a radius of 10. Their configurations vary based on the task.
#
# ### 3.1.1. State Representation
# A state \( s \) is defined as:
#
# $s = [(x_{\text{ROBOT}}, y_{\text{ROBOT}}), (x_{\text{SAND}}, y_{\text{SAND}})_1, \dots,
#     (x_{\text{SAND}}, y_{\text{SAND}})_N, (x_{\text{NOSAND}}, y_{\text{NOSAND}})_1, \dots,
#     (x_{\text{NOSAND}}, y_{\text{NOSAND}})_M)]$
#
# - $N$ is the number of sanding areas (circles)
# - $M$ is the number of no-sanding areas (circles)
# - $(x_{\text{ROBOT}}, y_{\text{ROBOT}})$ : Robot's current location
# - $(x_{\text{SAND}}, y_{\text{SAND}})_i$: Location of the $i$th sanding area
# - $(x_{\text{NOSAND}}, y_{\text{NOSAND}})_j$: Location of the $j$th no-sanding area
#
# ### 3.1.2. Action Space
#
# An action $a$ consists of target coordinates for the robot:
#
# $a = (a_x, a_y) \in \mathbb{R}^2$
#
# $a_x, a_y$ selects the current target coordinates of the robot arm. A PD-controller~\cite{X} trys to move the robot arm from the current coordinates $(x_{\text{ROBOT}}, y_{\text{ROBOT}})$ to the target coordinates $a_x, a_y$. You do not need to necessarily understand how exactly the PD-controller works but the controller may not always move the robot to the correct coordinates in one time step, and, it may also overshoot the target location. Please, see below for a visualization of this behavior.
#
#
# ### 3.1.3. Reward definition
#
# The reward is defined as the number of sanding locations the robot touches minus the number of no-sanding locations the robot touches, that is,
# $r_t = $ number of sanded sanding locations - number of sanded no-sanding locations .
#
# The robot can only sand a sanding or no-sanding location once. All sanding and no-sanding locations that are touched by the robot will be moved outside the operating area, that is, those locations will be outside the operating area in the subsequent time step.
#
#
# ## 3.2 Scenarios with different difficulty levels: <a id='3.1'></a>
#
#
# ### Environment Breakdown
# #### Environment 1: Easy Environment
#
# <p align="center">
#   <figure style="display:inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/easy_env.gif" alt="Easy Environment" width="180"/>
#   </figure>
# </p>
#
# - **No-Sanding Spots**: 1 (<span style="color:red">red</span>), fixed location in the center
# - **Sanding Spots**: 1 (<span style="color:green">green</span>), randomly generated without overlapping
# - **PD Control**: Movement to target \((a_x, a_y)\) with random number of PD iterations
# - **Notes**: Hollow circle indicates target, <span style="color:purple">purple</span> circle is the robot
#
# #### Environment 2: Moderate Difficulty Environment
# <p align="center">
#   <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/middle_env.gif" alt="Easy Environment" width="180"/>
#   </figure>
# </p>
#
# - **No-Sanding Spots**: 2 (<span style="color:red">red</span>), fixed locations along the diagonal
# - **Sanding Spots**: 2 (<span style="color:green">green</span>), randomly generated without overlapping
# - **Control**: Movement to target \((a_x, a_y)\) with random number of PD iterations
# - **Notes**: Hollow circle indicates target, <span style="color:purple">purple</span> circle is the robot
#
# #### Environment 3: Difficult Environment
# <p align="center">
#   <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/difficult_env.gif" alt="Easy Environment" width="180"/>
#   </figure>
# </p>
#
# - **No-Sanding Spots**: 4 (<span style="color:red">red</span>), fixed locations as a square
# - **Sanding Spots**: 4 (<span style="color:green">green</span>), one of which is fixed in the center while other three are ramdomly generated without overlapping
# - **Control**: Movement to target \((a_x, a_y)\) with random number of PD iterations
# - **Notes**: Hollow circle indicates target, <span style="color:purple">purple</span> circle is the robot
#
# # 4 Code Structure & Files <a id='4.'></a>
#
# ```project.ipynb``` is the main file needed to be modified for this project, but you can also add other auxiliary files if needed.
# ```
# ├───cfg
# │   ├───algo                       # Algorithm configurations
# │   ├───envs                       # Environment configurations
# ├───imgs                           # Images used in the notebook task description
# ├───utils                          # Utility functions
# ├───algo                           # Your agents (PPO/DDPG)
# ├───results                        # Training results
# ├───project.ipynb
# └───sanding.py                     # Sanding environment
#
# ```
#
#
# ## 4.1 Execution time <a id='4.1'></a>
#
# The training of DDPG/PPO may take more than 30 min for each run depending on the server load. If you have problems with the training time, you can train DDPG/PPO locally on your computer or a server.

# %% [markdown]
# # 5. Tasks <a id='5.'></a>
#
# ## I. Tasks 1: use following algorithms to solve the robot sanding task.
#   - **PPO** (you can take code from ex1 as a basis)
#   - **DDPG** (you can take code from ex6 as a basis)
#
# Implementations from the exercises can be used and extended, otherwise please implement algorithms yourself. For learning purposes, you can look at existing implementations on the Internet.
#
# - We do not want to focus on hyperparameter or neural network architecture tuning. Therefore, use the following choices:
#   - For PPO, use the neural network policy configuration found in exercise 1 code.
#   - For DDPG, use the neural network policy and value function configuration found in exercise 6 code.
#   - <span style="color:red">We provide the hyper-parameters in configuration files 'cfg/algo/*', DO NOT change the parameters there</span>
#
# - **No copying of code! Code should be original, written by yourself or taken from the exercises.**
#
# - You should extend or modify your basic PPO/DDPG algorithm. For each modification or extension, answer the multiple choice questions.
#
# - More detailed instructions are given in the following sections. If you are not sure what you are allowed or not allowed to do, contact the TAs, preferably on Zulip so that also others may learn from the question.
#
# **Note: not following the requirements may lead to point deduction or rejection of the project work.**
#
#
#
#
#
# ## II. Task 2: possible extensions to improve perfromance
#
# After the basic PPO/DDPG implementation, you shall try to do some technical improvements to improve the agent's performance. Below we list several possible extensions you can apply to improve the perfromance.
# - <span style="color:red">If you choose to implement PPO, for task 2 you can choose either Dual Clip PPO or Self imitation learning</span>
# - <span style="color:red">If you choose to implement DDPG, for task 2 you can choose either LNSS or Self imitation learning</span>
# - <span style="color:red">You should read the paper to do your own implementation and answer the related questions in Student Questions 1.</span>
# - <span style="color:red">The codes shall be implemented in "algo/ddpg_extension.py" or "algo/ppo_extension.py"</span>
#
# ### PPO based Extension: **Dual Clip PPO**
# - Implement it if your base algorithm is PPO.
# - It is designed to constrain updates to the policy, effectively preventing it from diverging excessively from its preceding iterations. This approach thereby ensures a more stable and reliable learning process during training.
# - Ref: ([Ye et al., 2020](https://ojs.aaai.org/index.php/AAAI/article/view/6144)).
#
#
#
# ### DDPG based Extension: **LNSS**
# - Implement it if your base algorithm is DDPG.
# - Its core idea is to improve N-step bootstrapping for off-policy RL like DDPG. It was empirically suggested that n-step methods perform better than single-step methods since n-step returns propagate rewards to relevant state-action pairs more efficientlyy.
# - Ref([Junmin et al., 2023](https://proceedings.neurips.cc/paper_files/paper/2023/file/29ef811e72b2b97cf18dd5d866b0f472-Paper-Conference.pdf)).
#
# ### General Extension: **Self imitation learning**
# - <span style="color:red">Either you implemented PPO or DDPG, you can choose to implement it instead of Dual Clip PPO or LN</span>
# - If you want to try a more general trick that can be used for any RL, you can implement self-imitatin learning.
# - It exploits past good experiences to drive deep exploration.
# - Ref:([Oh et al., 2018](https://proceedings.mlr.press/v80/oh18b.html)).
#
# ## III. Hints & Tips
#
# ### a) Hints
# - Due to the multidimensional actions, when using a Gaussian policy, remember to use a multivariate Gaussian probability distribution, or, product of standard Gaussian distributions that corresponds to a multivariate Gaussian distribution with a diagonal covariance matrix.

# %% [markdown]
# # <span> 6. Implementation requirements </span> <a id='6.'></a>
#
# ### <span> Your implemented algorithm must be compatible with the below requirements. This is the default behavior, however make sure not to disrupt it.</span>
#
# ## I. Data Saving Format
#
# ### a) Training Logs:
# During the training, your code shall create a CSV file as the training log.
#
#   - This log should output a CSV file with the following format:
#     ```
#     ,episode_length,ep_reward,episodes,total_step,average_return
#     0,20,0.0,99,2000,-0.13
#     1,20,0.0,199,4000,0.02
#     ...
#     ```
#   - The training log should be saved as:
#     `results/<environment name>/<algorithm name>/logging/logs_<seed number>.csv`
#
#     For example:
#     `results/SandingEnvDifficult/ddpg/logging/logs_0.csv`
#
#
# ### b) Model Weights
#
# During/after training, the policy/critic weights should be saved in the path:
#
#   `results/<environment name>/<algorithm name>/model/model_parameters_<seed number>.pt`
#
#   For example:
#
#   `results/SandingEnvDifficult/ddpg/model/model_parameters_0.pt`
#
#
#
#
# ## II. Visualization Plot Functions
#
# Ensure that your implemented algorithm is compatible with the functions located in `utils/common_utils.py`:
#
# - **Single Training Curve**:
#   - Function: `plot_reward(path, seed, env_name)`
#   - Description: Plots the training curve of a single algorithm, trained with a specific seed.
#
# - **Multiple Training Curves**:
#   - Function: `plot_algorithm_training(path, seeds, env_name)`
#   - Description: Plots the training curves of a single algorithm, trained with multiple specific random seeds.
#   - Example: `seeds=[0,1,2]`
#
# - **Comparison of Training Performances**:
#   - Function: `compare_algorithm_training(algo1, algo2, seeds)`
#   - Description: Given two configured algorithms/agents, this function will generate comparison plots of their training performances.
#
#
# ## III. <span style="color:red"> Configurations </span>
#
# We provide the hyperparameters in 'cfg/algo', use those configuration files to initialize your agent. Example refer to following code. You should not change any parameters there.
#
# **Usage Example**:
# ```python
# config = setup(algo='ppo', env='middle')
#     config["seed"] = 0
#     agent = PPOAgent(config)
# ```
#
# ## IV. <span style="color:red"> Training implementation </span>
#
# To ensure compatibility with the setup function, your implemented algorithm must follow the specified protocol:
#
# - **Function**: `setup(algo=None, env='easy', cfg_args={})`
#   - **Purpose**: Used for setting up the configurations.
#   - **Usage Example**:
#     ```python
#     config = setup(algo='ppo', env='middle')
#     config["seed"] = 0
#     agent = PPOAgent(config)
#     agent.train()
#     ```
#   - **Parameters**:
#     - `algo`: Specify the algorithm. Use either `'ppo'` or `'ddpg'`.
#     - `env`: Specify the environment. Options include `'easy'`, `'middle'`, or `'difficult'`.
#
# ## V. <span style="color:red"> Test implementation </span>
#
# To ensure compatibility with the setup function, your implemented algorithm must follow the specified protocol:
#
# - **Function**: `test`
#   - **Purpose**: Used for test the performance of the agent.
#   - **Usage Example**:
#     ```python
#     test(agent, env_name='easy', algo_name='ddpg')
#     ```
#
# ## VI. <span style="color:red"> Access </span>
#
# You should not modify any files in paths:
# - 'cfg/'
# - 'utils/'
# - 'sanding.py'
#
# ## VI. <span style="color:red"> Other tips </span>
#
# 1. If you choose DDPG based on ex6, you should be careful with function 'get_action()'. You should not use
# ```python
#     if self.buffer_ptr < self.random_transition:
# ```
# if you want to evluate the agent's performance when using:
# ```python
# test(agent, env_name='easy', algo_name='ddpg')
# ```
#
# 2. The standard deviation of gaussian policy in PPO is crucial for performance.
#
# ### <span style="color:red">Your implemented algorithm must be compatible with the above requirements; otherwise, the code will be considered invalid.</span>

# %% [markdown]
# # 7. Evaluation / Grading <a id='7.'></a>
#
# ### Grading
# The general evaluation and grading process will take into account the following aspects:
#
# - In Tasks 1, the grading will be based on the performance comparison between your algorithms and the respective baseline.
#     - If your implementation is able to run successfully, you get 10 points.
#     - <span style="color:red"> In order to get the full points of task 1, your implementation must have no statistically significant difference than our baseline performance (the average performance is provided below) </span>.
#     - We implmented the t-test in a hidden cell to automatically do the significant test and grading.
# - For Task 2 the grading will focus on the implemented extensions.
#     - If your extension is able to run successfully, you get 10 points.
#     - <span style="color:red"> In order to get the full points of task 2, the extension must have statistically significant better performance than the base algorithm </span>.
#     - We implmented the t-test in a hidden cell to do the check.
# - In Question 1, the evaluation will consider the created extensions. You will get points by correctly answering the given questions.
# - In Task 3, there will be a competitive grading approach: all projects will be evaluated based on their performance in the difficult Task 3 environment and then ranked. The best performing project (100% ranked) will receive 20 bonus points, 95% ranked or above will get 10 bonus points.
#
# ### Baseline Performance:
#
# The following values were recorded after running experiments for the base algorithms in different environments. Differences due to random conditions are expected.
#
# #### For PPO:
# - PPO (Easy Environment): mean: 0.75
# - PPO (Middle Environment): mean: 1.14
#
# #### For DDPG:
# - DDPG (Easy Environment): mean: 0.75
# - DDPG (Middle Environment): mean: 1.19
#
#
# #### Note:
#     - The PPO baseline is derived from the code used in Exercise 1, featuring a Gaussian policy with an isotropic covariance matrix. (For more details, please google "isotropic covariance matrix"). The log standard deviation of the policy is linearly scheduled from the initial log standard deviation to zero during the training.
#
#     - The DDPG baseline originates from the code used in Exercise 6. The exploration noise added to the action follows a Gaussian distribution (mean is 0 and standard deviation is 0.3).
#
# # 8. Start the project <a id='8.'></a>
#
# This section contains below all the source code including your implementation and the tasks and question that need to be filled.

# %% [markdown]
# <div class=" alert alert-warning">
#     <h3><b>Initialize the code</b> </h3>
#     Run the following section to start the task. DO NOT MODIFY THE CODE
# </div>

# %%
#Make sure to change this part before submission
skip_training = True  # Set this flag to True before validation and submission

# Make sure to change the algorithm_implemented variable to the algorithm you implemented
# This variable will be used in the evaluation and will determine which environment to use
# for both the baseline and the extension

algorithm_implemented = 'ppo' # "ddpg" or "ppo"

# %%
"TEST CELL"
# Out:
# 'TEST CELL'

# %%
#!pip install  imageio
# Out:
# Requirement already satisfied: imageio in /opt/software/lib/python3.10/site-packages (2.31.5)
# Requirement already satisfied: numpy in /opt/software/lib/python3.10/site-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /opt/software/lib/python3.10/site-packages (from imageio) (10.1.0)

# %%
import yaml
import gymnasium as gym

import numpy as np 
from types import SimpleNamespace as SN
from pathlib import Path
import copy
import utils.common_utils as cu
from utils.recorder import RecordVideo

# uncomment the following line to import the agent
#from algos.ddpg_agent import DDPGAgent
from algo.ppo_agent import PPOAgent

# %%
# Function to test a trained policy
def test(agent, env_name, algo_name):
    # Load model
    agent.load_model()
    print("Testing...")
    total_test_reward, total_test_len = 0, 0
    returns = []
    
    cur_dir=Path().cwd()
    cfg_path= cur_dir/'cfg'
    # read configuration parameters:
    cfg={'cfg_path': cfg_path, 'algo_name': algo_name}
    env_cfg=yaml.safe_load(open(cfg_path /'envs'/f'{env_name}_env.yaml', 'r'))
    
    # prepare folders to store results
    work_dir = cur_dir/'results'/env_cfg["env_name"]/algo_name
    video_test_dir=work_dir/"video"/"test"
    rng = np.random.default_rng(42)
    
    for ep in range(agent.cfg.test_episodes):
        seed = rng.integers(low=1, high=1000)
        observation, _ = agent.env.reset(seed=int(seed))
        test_reward, test_len, done = 0, 0, False
        
        if ep%100==0:
            frames = []

            while not done and test_len < agent.cfg.max_episode_steps:
                action, _ = agent.get_action(observation, evaluation=True)
                observation, reward, done, truncated, info = agent.env.step(action.flatten())
                fs = agent.env.render()
                frames = frames+fs
                test_reward += reward
                test_len += 1
            total_test_reward += test_reward
            total_test_len += test_len
            returns.append(test_reward)
            cu.save_rgb_arrays_to_gif(frames, video_test_dir/('_seed_'+str(agent.seed)+'_ep_'+str(ep)+'.gif'))
        else:
            
            while not done and test_len < agent.cfg.max_episode_steps:
                action, _ = agent.get_action(observation, evaluation=True)
                observation, reward, done, truncated, info = agent.env.step(action.flatten())
                test_reward += reward
                test_len += 1
            total_test_reward += test_reward
            total_test_len += test_len
            returns.append(test_reward)
       

    print(f"Average test reward over {len(returns)} episodes: {total_test_reward/agent.cfg.test_episodes},+- {np.std(np.array(returns))}; \
        Average episode length: {total_test_len/agent.cfg.test_episodes}")
    return returns

# %%
# Setup: read the configurations and generate the environment.
def setup(algo=None, env='easy', cfg_args={}, render=False, train_episodes=None):
    # set the paths
    cur_dir=Path().cwd()
    cfg_path= cur_dir/'cfg'
    
    # read configuration parameters:
    cfg={'cfg_path': cfg_path, 'algo_name': algo}
    env_cfg=yaml.safe_load(open(cfg_path /'envs'/f'{env}_env.yaml', 'r'))
    algo_cfg=yaml.safe_load(open(cfg_path /'algo'/f'{algo}.yaml', 'r'))
    cfg.update(env_cfg)
    cfg.update(algo_cfg)
    cfg.update(cfg_args)
    
    # forcely change train_episodes
    if train_episodes is None:
        True
    else:
        cfg["train_episodes"] = train_episodes
    
    # prepare folders to store results
    work_dir = cur_dir/'results'/cfg["env_name"]/str(algo)
    model_dir=work_dir/"model"
    logging_dir=work_dir/"logging"
    video_train_dir=work_dir/"video"/"train"
    video_test_dir=work_dir/"video"/"test"
    for dir in [work_dir, model_dir, logging_dir, video_train_dir, video_test_dir]:
        cu.make_dir(dir)
        
    cfg.update({'work_dir':work_dir, "model_dir":model_dir, "logging_dir": logging_dir, "video_train_dir": video_train_dir, "video_test_dir": video_test_dir})
    cfg = SN(**cfg)
    
    # set seed
    if cfg.seed == None:
        seed = np.random.randint(low=1, high=1000)
    else:
        seed = cfg.seed
    
    ## Create environment
    env=cu.create_env(cfg_path /'envs'/f'{env}_env.yaml')

   
    if cfg.save_video:
        # During testing, save every episode
        if cfg.testing:
            ep_trigger = 1
            video_path = cfg.video_test_dir
        # During training, save every 50th episode
        else:
            ep_trigger = 1000   # Save video every 50 episodes
            video_path = cfg.video_train_dir
        
        if render:
            env = RecordVideo(
                env, video_path,
                episode_trigger=lambda x: x % ep_trigger == 0,
                name_prefix=cfg.exp_name)


    eval_env=copy.deepcopy(env)
    env.reset(seed=seed) # we only set the seed here. During training, we don't have to set the seed when performing reset().
    eval_env.reset(seed=seed+1000)
    eval_env=None # For simplicity, we don't evaluate the performance during training.
        
    # Get dimensionalities of actions and observations
    action_space_dim = cu.get_space_dim(env.action_space)
    observation_space_dim = cu.get_space_dim(env.observation_space)
    
    config={
        "args": cfg,
        "env":env,
        "eval_env":eval_env,
        "action_space_dim": action_space_dim,
        "observation_space_dim": observation_space_dim,
        "seed":seed
    }
    return config

# %% [markdown]
# <a id='T1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 1</b> (30 points) </h3>
#     Implement the basic PPO or DDPG algorithm. Modify either the file 'ddpg_agent.py' or 'ppo_agent.py' in the folder 'algos'.
#
#     1. Choose PPO or DDPG
#
#     2. You can check our provided base's mean performance to check if your implementation's performance is acceptable.
#
#     2. Please document your results here, including the training plots and test performance.
#
#     3. Adhere to the given structure to facilitate testing with 'setup' and 'test'  function.
#
#     4. Run the algorithm in the 'easy' and 'middle' environments.
#
# </div>

# %% [markdown]
# ## Task 1.1: Train each agents' performance
#
# - Implement your algorithm (either DDPG or PPO) in algo/ddpg_agent.py or algo/ppo_agent.py
# - After the implementation, train your algorithm with the following code
#     - Train the algorithm in the first two environments
#     - The code will train the algorithm with 3 random seeds
# - Your code must be compatible with the following provided python code
#
# **Below, you will find an example of how to test your code**

# %%
# This part is provided only for debugging
if skip_training == False:
    train_episodes = 1000  # Limit the number of training episode for a fast test
    
    config=setup(algo='ppo', env='easy', train_episodes=train_episodes, render=False)
    
    config["seed"] = 43
    
    
    if config["args"].algo_name == 'ppo':
        agent=PPOAgent(config)
    #elif config["args"].algo_name == 'ddpg':
    #    agent=DDPGAgent(config)
    else:
        raise Exception('Please use ppo or ddpg!')
    
    # Train the agent using the selected algorithm    
    agent.train()
    test(agent, 'easy', 'ppo')
# Out:
# Episode 99 Step 2000 finished. Average episode return: -0.09 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: -0.07 (20 episode_length, Parameter containing:
# tensor([-0.0086, -0.0017], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.01 (20 episode_length, Parameter containing:
# tensor([-0.0223,  0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: -0.06 (20 episode_length, Parameter containing:
# tensor([-0.0323,  0.0042], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.17 (20 episode_length, Parameter containing:
# tensor([-0.0368, -0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.15 (20 episode_length, Parameter containing:
# tensor([-0.0332, -0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.22 (20 episode_length, Parameter containing:
# tensor([-0.0231, -0.0037], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.39 (20 episode_length, Parameter containing:
# tensor([-0.0180, -0.0011], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.35 (20 episode_length, Parameter containing:
# tensor([-0.0101,  0.0025], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.47 (20 episode_length, Parameter containing:
# tensor([-0.0028,  0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Saved model to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/model/model_parameters_43.pt ...
# logger and seed 43
# /notebooks/rl2024/project/results/SandingEnvEasy/ppo/logging/logs_43.csv
# ------Training finished.------
# Total traning time is 1.3876355681568384mins
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_43_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_43_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_43_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_43_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_43_ep_400.gif
# Average test reward over 500 episodes: 0.444,+- 0.5466845525529325;         Average episode length: 20.0

# %% [markdown]
# **If everything is fine, we start the proper training now**

# %%
## Code block for training and testing an agent using the implemented algorithm

if skip_training == False:
    # Choose either PPO or DDPG
    implemented_algo ='ppo'#'ppo' or 'ddpg'
    
    # Loop over the three difficulty levels
    environment = 'easy'
    training_seeds = []
        
    # Train the algorithm with a specific random seed.
    # In total, we train the algorithm with three random seeds [0, 1, 2].
    for i in range(3):
        config=setup(algo=implemented_algo, env=environment, render=True)
        config["seed"] = i
        training_seeds.append(i)
        if config["args"].algo_name == 'ppo':
            agent=PPOAgent(config)
        #elif config["args"].algo_name == 'ddpg':
        #    agent=DDPGAgent(config)
        else:
            raise Exception('Please use ppo or ddpg!')
    
        # Train the agent using selected algorithm    
        agent.train()
# Out:
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: -0.16 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: -0.1 (20 episode_length, Parameter containing:
# tensor([0.0045, 0.0098], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: -0.11 (20 episode_length, Parameter containing:
# tensor([ 0.0089, -0.0057], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: -0.05 (20 episode_length, Parameter containing:
# tensor([-0.0062, -0.0164], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.01 (20 episode_length, Parameter containing:
# tensor([-0.0308, -0.0366], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.21 (20 episode_length, Parameter containing:
# tensor([-0.0184, -0.0365], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.17 (20 episode_length, Parameter containing:
# tensor([-0.0216, -0.0477], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.22 (20 episode_length, Parameter containing:
# tensor([-0.0138, -0.0499], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.3 (20 episode_length, Parameter containing:
# tensor([-0.0242, -0.0380], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.45 (20 episode_length, Parameter containing:
# tensor([-0.0003, -0.0390], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.42 (20 episode_length, Parameter containing:
# tensor([-0.0209, -0.0352], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.28 (20 episode_length, Parameter containing:
# tensor([-0.0067, -0.0307], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.44 (20 episode_length, Parameter containing:
# tensor([-0.0098, -0.0417], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.34 (20 episode_length, Parameter containing:
# tensor([-0.0098, -0.0430], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.29 (20 episode_length, Parameter containing:
# tensor([-0.0069, -0.0395], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.42 (20 episode_length, Parameter containing:
# tensor([-0.0258, -0.0514], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.42 (20 episode_length, Parameter containing:
# tensor([-0.0194, -0.0343], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.65 (20 episode_length, Parameter containing:
# tensor([-0.0092, -0.0311], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.45 (20 episode_length, Parameter containing:
# tensor([ 0.0065, -0.0176], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.53 (20 episode_length, Parameter containing:
# tensor([ 0.0025, -0.0104], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.44 (20 episode_length, Parameter containing:
# tensor([ 0.0036, -0.0120], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.41 (20 episode_length, Parameter containing:
# tensor([ 0.0091, -0.0106], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.47 (20 episode_length, Parameter containing:
# tensor([-0.0132,  0.0047], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.49 (20 episode_length, Parameter containing:
# tensor([-0.0031,  0.0073], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.56 (20 episode_length, Parameter containing:
# tensor([0.0061, 0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.52 (20 episode_length, Parameter containing:
# tensor([ 0.0003, -0.0027], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 0.51 (20 episode_length, Parameter containing:
# tensor([ 0.0042, -0.0144], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.66 (20 episode_length, Parameter containing:
# tensor([ 0.0002, -0.0163], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.5 (20 episode_length, Parameter containing:
# tensor([-0.0028, -0.0068], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([-0.0010, -0.0080], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.58 (20 episode_length, Parameter containing:
# tensor([ 0.0075, -0.0114], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.63 (20 episode_length, Parameter containing:
# tensor([ 0.0017, -0.0051], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-9.7552e-05, -1.3270e-02], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-0.0010, -0.0027], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.7 (20 episode_length, Parameter containing:
# tensor([-0.0004, -0.0033], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0025,  0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0015, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([ 0.0026, -0.0022], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([ 0.0004, -0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 0.75 (20 episode_length, Parameter containing:
# tensor([-0.0004,  0.0038], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0038,  0.0001], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.81 (20 episode_length, Parameter containing:
# tensor([-0.0024, -0.0026], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([ 0.0019, -0.0005], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([ 0.0035, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([0.0025, 0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([1.8822e-03, 5.7490e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([-0.0016,  0.0014], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 0.72 (20 episode_length, Parameter containing:
# tensor([-3.5521e-06, -2.8668e-04], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([3.8091e-04, 8.2167e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0002,  0.0003], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/model/model_parameters_0.pt ...
# logger and seed 0
# /notebooks/rl2024/project/results/SandingEnvEasy/ppo/logging/logs_0.csv
# ------Training finished.------
# Total traning time is 6.927418838441372mins
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: 0.09 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.22 (20 episode_length, Parameter containing:
# tensor([ 0.0159, -0.0171], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.1 (20 episode_length, Parameter containing:
# tensor([ 0.0146, -0.0189], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.32 (20 episode_length, Parameter containing:
# tensor([ 0.0220, -0.0447], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.35 (20 episode_length, Parameter containing:
# tensor([ 0.0183, -0.0385], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.47 (20 episode_length, Parameter containing:
# tensor([ 0.0006, -0.0445], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.36 (20 episode_length, Parameter containing:
# tensor([-0.0169, -0.0572], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.52 (20 episode_length, Parameter containing:
# tensor([-0.0224, -0.0711], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.58 (20 episode_length, Parameter containing:
# tensor([-0.0384, -0.0592], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.56 (20 episode_length, Parameter containing:
# tensor([-0.0513, -0.0696], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([-0.0588, -0.0801], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([-0.0724, -0.0631], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.65 (20 episode_length, Parameter containing:
# tensor([-0.0666, -0.0530], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.61 (20 episode_length, Parameter containing:
# tensor([-0.0438, -0.0493], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([-0.0233, -0.0243], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0174, -0.0303], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0293, -0.0297], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.61 (20 episode_length, Parameter containing:
# tensor([-0.0250, -0.0268], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0280, -0.0188], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0384, -0.0247], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0412, -0.0305], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([-0.0272, -0.0152], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0355, -0.0122], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([-1.6876e-02, -7.5138e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0250,  0.0014], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0054, -0.0024], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0065, -0.0066], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([-0.0072, -0.0017], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([-0.0071, -0.0065], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0182, -0.0082], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([-0.0021,  0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([0.0028, 0.0011], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([-0.0056, -0.0009], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([ 0.0029, -0.0018], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0045, -0.0039], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([ 0.0007, -0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([-0.0054, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.7 (20 episode_length, Parameter containing:
# tensor([-0.0026, -0.0021], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([ 0.0010, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([ 0.0013, -0.0014], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([-0.0032, -0.0039], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0014, -0.0025], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0014,  0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0011, -0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([ 0.0016, -0.0001], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([ 0.0009, -0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0004, -0.0009], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0002,  0.0009], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0009, -0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-2.2945e-05,  1.6824e-04], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/model/model_parameters_1.pt ...
# logger and seed 1
# /notebooks/rl2024/project/results/SandingEnvEasy/ppo/logging/logs_1.csv
# ------Training finished.------
# Total traning time is 6.939430147533615mins
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: -0.15 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: -0.02 (20 episode_length, Parameter containing:
# tensor([-0.0026,  0.0091], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.06 (20 episode_length, Parameter containing:
# tensor([0.0243, 0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.16 (20 episode_length, Parameter containing:
# tensor([ 0.0409, -0.0196], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.21 (20 episode_length, Parameter containing:
# tensor([ 0.0465, -0.0305], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.32 (20 episode_length, Parameter containing:
# tensor([ 0.0436, -0.0374], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.33 (20 episode_length, Parameter containing:
# tensor([ 0.0400, -0.0505], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.43 (20 episode_length, Parameter containing:
# tensor([ 0.0239, -0.0560], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.36 (20 episode_length, Parameter containing:
# tensor([ 0.0095, -0.0587], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.43 (20 episode_length, Parameter containing:
# tensor([-0.0023, -0.0752], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.52 (20 episode_length, Parameter containing:
# tensor([-0.0192, -0.0619], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.51 (20 episode_length, Parameter containing:
# tensor([-0.0198, -0.0648], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.49 (20 episode_length, Parameter containing:
# tensor([-0.0228, -0.0544], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.66 (20 episode_length, Parameter containing:
# tensor([-0.0429, -0.0704], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([-0.0306, -0.0637], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0252, -0.0493], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0281, -0.0382], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([-0.0199, -0.0424], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.62 (20 episode_length, Parameter containing:
# tensor([-0.0156, -0.0429], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-0.0087, -0.0376], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0081, -0.0286], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0136, -0.0192], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0069, -0.0123], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([-0.0197, -0.0132], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([-0.0180, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0118, -0.0154], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([-0.0076, -0.0049], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.81 (20 episode_length, Parameter containing:
# tensor([-0.0128, -0.0060], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-0.0048, -0.0102], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0004, -0.0089], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([ 0.0031, -0.0036], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([ 0.0014, -0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.72 (20 episode_length, Parameter containing:
# tensor([-0.0026,  0.0044], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([-0.0016,  0.0004], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([-0.0070, -0.0087], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.72 (20 episode_length, Parameter containing:
# tensor([-0.0065,  0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([-0.0011, -0.0083], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-0.0052, -0.0053], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([ 0.0004, -0.0048], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([-0.0041, -0.0069], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0004, -0.0001], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0007,  0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([-0.0019, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([ 0.0016, -0.0046], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0011,  0.0004], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([-0.0024,  0.0014], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([ 0.0001, -0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([-0.0009, -0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-7.9348e-05,  1.6935e-04], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0001, -0.0003], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/model/model_parameters_2.pt ...
# logger and seed 2
# /notebooks/rl2024/project/results/SandingEnvEasy/ppo/logging/logs_2.csv
# ------Training finished.------
# Total traning time is 6.960811640694738mins

# %%
## Code block for training and testing an agent using the implemented algorithm

if skip_training == False:
    # Choose either PPO or DDPG
    implemented_algo ='ppo'#'ppo' or 'ddpg'
    
    # Loop over the three difficulty levels
    environment = 'middle'
    training_seeds = []
    
    # Train the algorithm with a specific random seed.
    # In total, we train the algorithm with three random seeds [0, 1, 2].
    for i in range(3):
        config=setup(algo=implemented_algo, env=environment,render=True)
        config["seed"] = i
        training_seeds.append(i)
        if config["args"].algo_name == 'ppo':
            agent=PPOAgent(config)
        #elif config["args"].algo_name == 'ddpg':
        #    agent=DDPGAgent(config)
        else:
            raise Exception('Please use ppo or ddpg!')
    
        # Train the agent using selected algorithm    
        agent.train()
# Out:
# /opt/software/lib/python3.10/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /notebooks/rl2024/project/utils/recorder.py:250: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:300: UserWarning: WARN: RGB-array rendering should return a numpy array, got <class 'list'>
#   logger.warn(
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /notebooks/rl2024/project/algo/ppo_agent.py:92: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1699449045676/work/torch/csrc/utils/tensor_new.cpp:261.)
#   self.actions.append(torch.Tensor([action]))
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: -0.04 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.12 (20 episode_length, Parameter containing:
# tensor([ 0.0182, -0.0192], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.06 (20 episode_length, Parameter containing:
# tensor([ 0.0019, -0.0209], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.14 (20 episode_length, Parameter containing:
# tensor([-0.0023, -0.0205], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.36 (20 episode_length, Parameter containing:
# tensor([-0.0084, -0.0389], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.56 (20 episode_length, Parameter containing:
# tensor([-0.0287, -0.0707], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.65 (20 episode_length, Parameter containing:
# tensor([-0.0619, -0.0613], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([-0.0779, -0.0658], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([-0.0691, -0.0805], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([-0.0553, -0.0747], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.65 (20 episode_length, Parameter containing:
# tensor([-0.0539, -0.0856], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([-0.0468, -0.0816], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([-0.0475, -0.0716], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.75 (20 episode_length, Parameter containing:
# tensor([-0.0354, -0.0400], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.75 (20 episode_length, Parameter containing:
# tensor([-0.0242, -0.0485], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([-0.0291, -0.0375], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0254, -0.0213], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0305, -0.0217], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.81 (20 episode_length, Parameter containing:
# tensor([-0.0305, -0.0161], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.91 (20 episode_length, Parameter containing:
# tensor([-0.0211, -0.0051], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.92 (20 episode_length, Parameter containing:
# tensor([-0.0166, -0.0210], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0029, -0.0129], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([-0.0030, -0.0152], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.9 (20 episode_length, Parameter containing:
# tensor([-0.0094, -0.0096], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.91 (20 episode_length, Parameter containing:
# tensor([ 0.0040, -0.0120], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([-0.0033, -0.0182], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([-0.0081, -0.0185], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([-0.0066, -0.0138], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0065, -0.0107], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([ 0.0053, -0.0096], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([-0.0048, -0.0124], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([-0.0020, -0.0068], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 1.05 (20 episode_length, Parameter containing:
# tensor([-0.0030, -0.0086], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([-0.0062, -0.0035], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([-0.0046, -0.0080], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([-0.0032, -0.0064], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0031, -0.0021], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([-0.0043, -0.0028], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 0.93 (20 episode_length, Parameter containing:
# tensor([-5.1970e-03,  7.8897e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 0.9 (20 episode_length, Parameter containing:
# tensor([-0.0042,  0.0009], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 0.81 (20 episode_length, Parameter containing:
# tensor([-0.0033, -0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.9 (20 episode_length, Parameter containing:
# tensor([-0.0029, -0.0028], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.91 (20 episode_length, Parameter containing:
# tensor([-0.0011, -0.0051], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.98 (20 episode_length, Parameter containing:
# tensor([ 0.0011, -0.0019], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 0.95 (20 episode_length, Parameter containing:
# tensor([-0.0023, -0.0019], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([-0.0010, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 0.93 (20 episode_length, Parameter containing:
# tensor([-0.0010, -0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([-0.0016,  0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 0.93 (20 episode_length, Parameter containing:
# tensor([-7.0314e-05, -3.2699e-04], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 0.91 (20 episode_length, Parameter containing:
# tensor([-2.6575e-04,  7.5729e-05], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4
# /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment SandingEnvMiddle already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /opt/software/lib/python3.10/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /notebooks/rl2024/project/utils/recorder.py:250: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:300: UserWarning: WARN: RGB-array rendering should return a numpy array, got <class 'list'>
#   logger.warn(
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/model/model_parameters_0.pt ...
# logger and seed 0
# /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/logging/logs_0.csv
# ------Training finished.------
# Total traning time is 6.962749054779609mins
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: 0.45 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.4 (20 episode_length, Parameter containing:
# tensor([0.0146, 0.0175], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([0.0041, 0.0162], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.5 (20 episode_length, Parameter containing:
# tensor([0.0098, 0.0185], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.61 (20 episode_length, Parameter containing:
# tensor([0.0082, 0.0045], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([0.0051, 0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.61 (20 episode_length, Parameter containing:
# tensor([-0.0094, -0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.43 (20 episode_length, Parameter containing:
# tensor([ 0.0007, -0.0157], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.55 (20 episode_length, Parameter containing:
# tensor([-0.0005, -0.0056], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.62 (20 episode_length, Parameter containing:
# tensor([-0.0036, -0.0074], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.65 (20 episode_length, Parameter containing:
# tensor([-0.0039, -0.0060], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([-0.0058, -0.0246], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.72 (20 episode_length, Parameter containing:
# tensor([-0.0063, -0.0101], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.63 (20 episode_length, Parameter containing:
# tensor([ 0.0093, -0.0204], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([ 0.0275, -0.0098], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([ 0.0124, -0.0103], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([ 0.0008, -0.0151], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0058, -0.0111], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([-0.0107, -0.0031], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.63 (20 episode_length, Parameter containing:
# tensor([ 0.0133, -0.0081], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([ 0.0115, -0.0159], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([ 0.0099, -0.0118], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([ 0.0128, -0.0037], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([ 0.0119, -0.0069], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([ 0.0023, -0.0087], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([-0.0062,  0.0048], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0008, -0.0037], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([-0.0017, -0.0045], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.7 (20 episode_length, Parameter containing:
# tensor([-0.0070,  0.0026], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([ 0.0020, -0.0064], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([0.0020, 0.0024], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([0.0009, 0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([ 0.0039, -0.0029], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.81 (20 episode_length, Parameter containing:
# tensor([ 0.0043, -0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0035,  0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0055,  0.0023], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([-0.0059, -0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([-0.0046, -0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 0.92 (20 episode_length, Parameter containing:
# tensor([-0.0012, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0021,  0.0035], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([-0.0020, -0.0024], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.89 (20 episode_length, Parameter containing:
# tensor([-0.0032,  0.0027], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0017, -0.0032], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.94 (20 episode_length, Parameter containing:
# tensor([-0.0029,  0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0005, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-9.9893e-05, -1.2252e-03], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([ 0.0011, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 0.9 (20 episode_length, Parameter containing:
# tensor([-0.0014, -0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([ 6.2304e-04, -3.3767e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([ 0.0002, -0.0002], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/model/model_parameters_1.pt ...
# logger and seed 1
# /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/logging/logs_1.csv
# ------Training finished.------
# Total traning time is 7.044490982343754mins
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: -0.09 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.05 (20 episode_length, Parameter containing:
# tensor([ 0.0016, -0.0092], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.07 (20 episode_length, Parameter containing:
# tensor([-0.0109, -0.0137], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.16 (20 episode_length, Parameter containing:
# tensor([-0.0288, -0.0096], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.21 (20 episode_length, Parameter containing:
# tensor([-0.0507, -0.0177], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.22 (20 episode_length, Parameter containing:
# tensor([-0.0630, -0.0264], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.4 (20 episode_length, Parameter containing:
# tensor([-0.0787, -0.0363], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.52 (20 episode_length, Parameter containing:
# tensor([-0.0829, -0.0314], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.62 (20 episode_length, Parameter containing:
# tensor([-0.0750, -0.0236], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.53 (20 episode_length, Parameter containing:
# tensor([-0.0687, -0.0181], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.7 (20 episode_length, Parameter containing:
# tensor([-0.0639, -0.0155], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.61 (20 episode_length, Parameter containing:
# tensor([-0.0686, -0.0091], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([-0.0589, -0.0078], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([-0.0617, -0.0028], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([-0.0559, -0.0054], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([-0.0513, -0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0616, -0.0089], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 1.0 (20 episode_length, Parameter containing:
# tensor([-0.0311, -0.0217], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0406, -0.0167], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0171, -0.0095], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.9 (20 episode_length, Parameter containing:
# tensor([-0.0170, -0.0096], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 1.05 (20 episode_length, Parameter containing:
# tensor([-0.0066, -0.0235], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.95 (20 episode_length, Parameter containing:
# tensor([-0.0075, -0.0124], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.92 (20 episode_length, Parameter containing:
# tensor([-0.0099, -0.0050], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.93 (20 episode_length, Parameter containing:
# tensor([-0.0185, -0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.95 (20 episode_length, Parameter containing:
# tensor([-0.0137, -0.0101], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 1.02 (20 episode_length, Parameter containing:
# tensor([-0.0084, -0.0019], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 1.01 (20 episode_length, Parameter containing:
# tensor([-0.0042,  0.0033], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.98 (20 episode_length, Parameter containing:
# tensor([-0.0043,  0.0021], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 1.06 (20 episode_length, Parameter containing:
# tensor([-0.0073,  0.0010], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([-0.0066, -0.0027], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 1.22 (20 episode_length, Parameter containing:
# tensor([-0.0090, -0.0033], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 1.02 (20 episode_length, Parameter containing:
# tensor([-0.0105, -0.0054], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.98 (20 episode_length, Parameter containing:
# tensor([-0.0080, -0.0079], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.97 (20 episode_length, Parameter containing:
# tensor([-0.0094, -0.0049], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.99 (20 episode_length, Parameter containing:
# tensor([-7.9963e-03, -2.1817e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 1.0 (20 episode_length, Parameter containing:
# tensor([-0.0045,  0.0050], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([0.0008, 0.0029], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 1.23 (20 episode_length, Parameter containing:
# tensor([-0.0021,  0.0017], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 1.06 (20 episode_length, Parameter containing:
# tensor([0.0007, 0.0011], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 1.06 (20 episode_length, Parameter containing:
# tensor([-0.0038, -0.0028], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 1.17 (20 episode_length, Parameter containing:
# tensor([-0.0027, -0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.95 (20 episode_length, Parameter containing:
# tensor([-0.0013,  0.0019], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 1.14 (20 episode_length, Parameter containing:
# tensor([0.0011, 0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 1.25 (20 episode_length, Parameter containing:
# tensor([-0.0019, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([-0.0019,  0.0005], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 1.38 (20 episode_length, Parameter containing:
# tensor([-0.0009,  0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 1.34 (20 episode_length, Parameter containing:
# tensor([-0.0014,  0.0004], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 1.14 (20 episode_length, Parameter containing:
# tensor([-0.0006, -0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 1.13 (20 episode_length, Parameter containing:
# tensor([-0.0002, -0.0001], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/model/model_parameters_2.pt ...
# logger and seed 2
# /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/logging/logs_2.csv
# ------Training finished.------
# Total traning time is 7.001441163321336mins

# %% [markdown]
# ## Task 1.2: Evaluate the Performance of Each Agent
#
# For each environment, the algorithm has been trained using three different random seeds, resulting in the generation of three distinct models for each algorithm. Our next step is to assess the performance of each model.
#
# - Execute the code below and document the performance of each model:
#
# - Report the mean and standard deviation of the performance across the three random seeds.
#
# - Use the provided report format below, and input the values based on the results of your experiments.

# %%
## Code block for training and testing an agent using the implemented algorithm
## in the three different Tasks with different difficulty levels
import warnings
warnings.filterwarnings('ignore')
if skip_training == False:
    # NOTE: Uncomment the algorithm you implemented
    implemented_algo ='ppo' #'ddpg' or 'ppo'
    
    # Loop over the three difficulty levels
    for environment in ['easy', 'middle']:
    
        training_seeds = []
        
        # for each algorithm, we will test the agent trained with specific random seed
        for i in range(3):
            config=setup(algo=implemented_algo, env=environment)
    
            config["seed"] = i
            training_seeds.append(i)
    
            if config["args"].algo_name == 'ppo':
                agent=PPOAgent(config)
            #elif config["args"].algo_name == 'ddpg':
            #    agent=DDPGAgent(config)
            else:
                raise Exception('Please use ppo or ddpg!')
            
            print('\n\n\nnow start testing for environment',environment,' agent:',implemented_algo,' seed:',i)
            # Test the agent in the selected environment
            test(agent, environment, implemented_algo)
# Out:
# now start testing for environment easy  agent: ppo  seed: 0
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_0_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_0_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_0_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_0_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_0_ep_400.gif
# Average test reward over 500 episodes: 0.632,+- 0.48226133993924913;         Average episode length: 20.0
#
#
#
# now start testing for environment easy  agent: ppo  seed: 1
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_1_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_1_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_1_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_1_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_1_ep_400.gif
# Average test reward over 500 episodes: 0.712,+- 0.4572264209338738;         Average episode length: 20.0
#
#
#
# now start testing for environment easy  agent: ppo  seed: 2
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_2_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_2_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_2_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_2_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvEasy/ppo/video/test/_seed_2_ep_400.gif
# Average test reward over 500 episodes: 0.684,+- 0.46491289506745237;         Average episode length: 20.0
#
#
#
# now start testing for environment middle  agent: ppo  seed: 0
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_0_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_0_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_0_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_0_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_0_ep_400.gif
# Average test reward over 500 episodes: 0.926,+- 0.6756655977626801;         Average episode length: 20.0
#
#
#
# now start testing for environment middle  agent: ppo  seed: 1
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_1_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_1_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_1_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_1_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_1_ep_400.gif
# Average test reward over 500 episodes: 0.796,+- 0.6437266500619654;         Average episode length: 20.0
#
#
#
# now start testing for environment middle  agent: ppo  seed: 2
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_2_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_2_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_2_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_2_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo/video/test/_seed_2_ep_400.gif
# Average test reward over 500 episodes: 0.99,+- 0.762823701781742;         Average episode length: 20.0

# %% [markdown]
# If you are curious about visualizing policy behaviours, you can run the following code

# %%
            
# The example of visualizing the saved test GIFs
from IPython.display import display, Image
if skip_training == False:
# Display the GIF in Jupyter
    display(Image(filename="imgs/difficult_env.gif"))  # Change the file path to display yours

# %% [markdown]
# ## Task 1.3: Plot the algorithm's performance in each environment
#
# If all above code runs successfully, now we want to make a plot of the algorithm's training performance. You can run the code below to make plots. The training performance will look similar to this:
#
# <p align="center">
#   <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/ppo_statistical_SandingEnvEasy.png" alt="PPO Easy Environment" width="240"/>
#     <figcaption>PPO Easy</figcaption>
#   </figure>
#   <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/ppo_statistical_SandingEnvMiddle.png" alt="PPO Middle Environment" width="240"/>
#     <figcaption>PPO Middle</figcaption>
#   </figure>
#   <!-- <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/ppo_statistical_SandingEnvDifficult.png" alt="PPO Difficult Environment" width="240"/>
#     <figcaption>PPO Difficult</figcaption>
#   </figure> -->
# </p>
# <p align="center">
#   <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/ddpg_statistical_SandingEnvEasy.png" alt="DDPG Easy Environment" width="240"/>
#     <figcaption>DDPG Easy</figcaption>
#   </figure>
#   <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/ddpg_statistical_SandingEnvMiddle.png" alt="DDPG Middle Environment" width="240"/>
#     <figcaption>DDPG Middle</figcaption>
#   </figure>
#   <!-- <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/ddpg_statistical_SandingEnvDifficult.png" alt="DDPG Difficult Environment" width="240"/>
#     <figcaption>DDPG Difficult</figcaption>
#   </figure> -->
# </p>
#
# **Note**: You do not need to make the plots look exactly the same as shown above.  The following code generates 3 figures (1 algorithm x 3 environments). Please comment below the algorithm you did not implement.
#
# ### Paths:
# Your plot should be plotted in the following paths if the code runs successfully:
#
# - **PPO Easy**:
#   - `results/SandingEnvMiddle/ppo/logging/figure_statistical_SandingEnvEasy.pdf`
# - **PPO Middle**:
#   - `results/SandingEnvMiddle/ppo/logging/figure_statistical_SandingEnvMiddle.pdf`
# <!-- - **PPO Difficult**:
#   - `results/SandingEnvMiddle/PPO/logging/figure_statistical_SandingEnvDifficult.pdf` -->

# %% [markdown]
#  or
#
# - **DDPG Easy**:
#   - `results/SandingEnvMiddle/ddpg/logging/figure_statistical_SandingEnvEasy.pdf`
# - **DDPG Middle**:
#   - `results/SandingEnvMiddle/ddpg/logging/figure_statistical_SandingEnvMiddle.pdf`
# <!-- - **DDPG Difficult**:
#   - `results/SandingEnvMiddle/DDPG/logging/figure_statistical_SandingEnvDifficult.pdf` -->

# %%
## Run the following code to plot PPO or DDPG's training performances
import warnings
warnings.filterwarnings('ignore')
if skip_training == False:
    # Uncomment the algorithm you chose 
    implemented_algo ='ppo' # 'ppo' or 'ddpg'
    
    
    # Loop over the three difficulty levels
    for environment in ['easy', 'middle']:
    
        training_seeds = []
        for i in range(3):
            config=setup(algo=implemented_algo, env=environment)
    
            config["seed"] = i
            training_seeds.append(i)
    
    
            if config["args"].algo_name == 'ppo':
                agent=PPOAgent(config)
            #elif config["args"].algo_name == 'ddpg':
            #    agent=DDPGAgent(config)
            else:
                raise Exception('Please use ppo or ddpg!')
    
        # plot the statistical training curves with specific random seeds
        cu.plot_algorithm_training(agent.logging_dir, training_seeds, agent.env_name, implemented_algo)

# %% [markdown]
# DOUBLE CLICK HERE TO EDIT, RUN the above code to make training plots for each algorithm

# %% [markdown]
# The following cells are used for testing.

# %%
# Function to test a trained policy
def grading_test(agent, env_name, algo_name):
    # Load model
    agent.load_model()
    returns = []
    rng = np.random.default_rng(42)
    
    for ep in range(agent.cfg.test_episodes):
        seed = rng.integers(low=1, high=1000)
        observation, _ = agent.env.reset(seed=int(seed))
        test_reward, test_len, done = 0, 0, False
        
            
        while not done and test_len < agent.cfg.max_episode_steps:
            action, _ = agent.get_action(observation, evaluation=True)
            observation, reward, done, truncated, info = agent.env.step(action.flatten())
            test_reward += reward
            test_len += 1
        returns.append(test_reward)
    return returns

# %% [markdown]
# Compares the performance of your algorithm with the baseline in order to check that there is no statistical significant difference.

# %%
warnings.filterwarnings('ignore')

environment = 'easy'

def test_task1_1():
    baseline_test_returns = []

    for i in range(3):
        config=setup(algo=algorithm_implemented, env=environment, render=False)
        config["seed"] = i
        if config["args"].algo_name == 'ppo':
            agent=PPOAgent(config)
        elif config["args"].algo_name == 'ddpg':
            agent=DDPGAgent(config)
        else:
            raise Exception('Please use ppo or ddpg!')

        baseline_test_returns.append(np.sum(grading_test(agent, environment, algorithm_implemented))/agent.cfg.test_episodes)

    if algorithm_implemented == 'ppo':
        ppo_easy_baseline_target = np.array([0.738, 0.79, 0.78, 0.8,  0.798, 0.774, 0.802, 0.754,  0.756,  0.554])
        better_performance = np.mean(baseline_test_returns) > np.mean(ppo_easy_baseline_target)
        assert not cu.test_significant_difference(ppo_easy_baseline_target, np.array(baseline_test_returns), 0.05) or better_performance
    elif algorithm_implemented == 'ddpg':
        ddpg_easy_baseline_target =  np.array([ 0.83, 0.792, 0.804,  0.654, 0.562, 0.8, 0.888, 0.714, 0.724, 0.774])
        better_performance = np.mean(baseline_test_returns) > np.mean(ddpg_easy_baseline_target)
        assert not cu.test_significant_difference(ddpg_easy_baseline_target, np.array(baseline_test_returns), 0.05) or better_performance


test_task1_1()

# %% [markdown]
# <a id='T2'></a>
# <div class="alert alert-warning">
#     <h3><b>Student Task 2</b> (40 points)</h3>
#     Your objective in this task is to enhance the performance of the DDPG/PPO algorithms, taking inspiration from the suggestions provided in <b>Section 5.II</b>.
#
#     1. You must elevate the base algorithm's performance to ensure the agent's success in the moderate difficulty environment (environment = 'middle').
#
#     2. Please document your results here, including the training plots and test performance.
#
#     3. Adhere to the given structure to facilitate testing with 'setup' and 'test'  function.
#
#     4. If you choose PPO, implement either Dual-Clip PPO or Self Imitation Learning (SIL).
#
#     5. If you opt for DDPG, implement either LNSS DDPG or SIL.
#
#     6. Carefully read the extension guidelines outlined in <b>Section 5.II</b>, and proceed to modify either 'ddpg_extension.py' or 'ppo_extension.py' located in the 'algos' folder.
#
# </div>

# %% [markdown]
# ## Task 2.1: Enhance Your Chosen Algorithm
#
# ### a) Overview
# Improve the performance of your selected reinforcement learning algorithm. Ensure that your implementations are properly documented and organized for clarity.
#
# ### b) Implementation Details
# - **Algorithm Improvements**: Enhance your chosen algorithm.
#   - If you choose PPO, implement either Dual-Clip PPO or Self Imitation Learning (SIL)
#   -  If you opt for DDPG, implement either LNSS  or SIL.
#   - Ensure that the performance is noticeably improved.
#   - Place your implementations in the appropriate file:
#     - 'algo/ddpg_extension.py' for DDPG
#     - 'algo/ppo_extension.py' for PPO
#
# ### c) Training
# - **Random Seeds**: Train your algorithm using three distinct random seeds [0,1,2] to ensure robustness and repeatability.
#
# ### d) Evaluation
# - **Environment**: Evaluate your algorithm exclusively in the **middle-level difficulty environment** to focus your improvements.
#
# ### e) Code Compatibility
# - Ensure that your code is **fully compatible** with all existing functions in other files, maintaining the integrity of the overall project structure.
#
# ---

# %% [markdown]
# **Train**: After implementing the improvement extensions, run the following code to train your agents.

# %%
# Implement your improved algorithm either in algo/ddpg_extension.py or algo/ppo_extension.py
# uncomment the following line to import the agent
#from algo.ddpg_extension import DDPGExtension
from algo.ppo_extension import PPOExtension

implemented_algo = 'ppo_extension'# choose 'ppo_extension' or 'ddpg_extension'
environment = 'middle'
if skip_training == False:
    training_seeds = []
    for i in range(3):
        config=setup(algo=implemented_algo, env=environment, render=True)
    
        config["seed"] = i
        training_seeds.append(i)
    
    
        if config["args"].algo_name == 'ppo_extension':
            agent=PPOExtension(config)
        #elif config["args"].algo_name == 'ddpg_extension':
        #    agent=DDPGExtension(config)
        else:
            raise Exception('Please use ppo or ddpg!')
    
        # Train the agent using selected algorithm    
        agent.train()
# Out:
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: 0.33 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.08 (20 episode_length, Parameter containing:
# tensor([-0.0099, -0.0079], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.33 (20 episode_length, Parameter containing:
# tensor([-0.0234, -0.0086], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.46 (20 episode_length, Parameter containing:
# tensor([-0.0160,  0.0228], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.38 (20 episode_length, Parameter containing:
# tensor([0.0017, 0.0292], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.51 (20 episode_length, Parameter containing:
# tensor([0.0171, 0.0478], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([0.0035, 0.0310], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.49 (20 episode_length, Parameter containing:
# tensor([0.0102, 0.0249], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.63 (20 episode_length, Parameter containing:
# tensor([-0.0008,  0.0331], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([0.0048, 0.0298], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([0.0120, 0.0022], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.66 (20 episode_length, Parameter containing:
# tensor([-0.0042, -0.0046], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0096, -0.0160], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0019, -0.0102], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.94 (20 episode_length, Parameter containing:
# tensor([-0.0154, -0.0099], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([ 0.0018, -0.0081], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([-0.0053,  0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.88 (20 episode_length, Parameter containing:
# tensor([-0.0065,  0.0091], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.89 (20 episode_length, Parameter containing:
# tensor([-0.0193,  0.0051], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.89 (20 episode_length, Parameter containing:
# tensor([-0.0210,  0.0084], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.95 (20 episode_length, Parameter containing:
# tensor([-0.0228,  0.0217], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([-0.0210,  0.0041], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 1.0 (20 episode_length, Parameter containing:
# tensor([-0.0097,  0.0028], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 1.0 (20 episode_length, Parameter containing:
# tensor([ 0.0018, -0.0125], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.95 (20 episode_length, Parameter containing:
# tensor([ 0.0134, -0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.9 (20 episode_length, Parameter containing:
# tensor([0.0061, 0.0036], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([ 0.0124, -0.0061], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 1.0 (20 episode_length, Parameter containing:
# tensor([ 0.0061, -0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.93 (20 episode_length, Parameter containing:
# tensor([0.0044, 0.0062], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 1.05 (20 episode_length, Parameter containing:
# tensor([0.0010, 0.0079], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 1.13 (20 episode_length, Parameter containing:
# tensor([0.0101, 0.0001], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 1.13 (20 episode_length, Parameter containing:
# tensor([0.0068, 0.0022], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 1.08 (20 episode_length, Parameter containing:
# tensor([0.0103, 0.0054], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 1.06 (20 episode_length, Parameter containing:
# tensor([-0.0004,  0.0055], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 1.16 (20 episode_length, Parameter containing:
# tensor([-0.0003, -0.0069], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.96 (20 episode_length, Parameter containing:
# tensor([ 0.0006, -0.0022], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 1.08 (20 episode_length, Parameter containing:
# tensor([0.0009, 0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 1.15 (20 episode_length, Parameter containing:
# tensor([-0.0021,  0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 1.12 (20 episode_length, Parameter containing:
# tensor([0.0035, 0.0053], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([ 0.0010, -0.0002], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 1.09 (20 episode_length, Parameter containing:
# tensor([-0.0005, -0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 1.29 (20 episode_length, Parameter containing:
# tensor([ 0.0037, -0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 1.23 (20 episode_length, Parameter containing:
# tensor([-0.0004, -0.0001], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 1.25 (20 episode_length, Parameter containing:
# tensor([0.0024, 0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 1.28 (20 episode_length, Parameter containing:
# tensor([ 0.0003, -0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 1.28 (20 episode_length, Parameter containing:
# tensor([ 0.0023, -0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 1.27 (20 episode_length, Parameter containing:
# tensor([-0.0021,  0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 1.17 (20 episode_length, Parameter containing:
# tensor([ 0.0003, -0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 1.16 (20 episode_length, Parameter containing:
# tensor([-5.1203e-05, -7.3402e-04], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 1.17 (20 episode_length, Parameter containing:
# tensor([ 6.5320e-05, -3.3836e-04], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/model/model_parameters_0.pt ...
# logger and seed 0
# /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/logging/logs_0.csv
# ------Training finished.------
# Total traning time is 7.096323563158512mins
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: -0.31 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: -0.26 (20 episode_length, Parameter containing:
# tensor([ 0.0316, -0.0167], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.04 (20 episode_length, Parameter containing:
# tensor([ 0.0609, -0.0042], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.51 (20 episode_length, Parameter containing:
# tensor([ 0.0473, -0.0111], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([0.0545, 0.0096], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.7 (20 episode_length, Parameter containing:
# tensor([0.0375, 0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([0.0163, 0.0144], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([0.0058, 0.0202], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.85 (20 episode_length, Parameter containing:
# tensor([0.0071, 0.0055], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.93 (20 episode_length, Parameter containing:
# tensor([-0.0149, -0.0113], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0341,  0.0009], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 1.16 (20 episode_length, Parameter containing:
# tensor([-0.0260, -0.0177], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 1.13 (20 episode_length, Parameter containing:
# tensor([-0.0318, -0.0099], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 1.2 (20 episode_length, Parameter containing:
# tensor([-0.0219, -0.0248], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 1.13 (20 episode_length, Parameter containing:
# tensor([-0.0097, -0.0181], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 1.11 (20 episode_length, Parameter containing:
# tensor([-0.0214, -0.0105], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 1.28 (20 episode_length, Parameter containing:
# tensor([-0.0213, -0.0259], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 1.19 (20 episode_length, Parameter containing:
# tensor([-0.0093, -0.0167], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 1.19 (20 episode_length, Parameter containing:
# tensor([-0.0178, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 1.29 (20 episode_length, Parameter containing:
# tensor([-0.0207, -0.0038], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 1.3 (20 episode_length, Parameter containing:
# tensor([-0.0156, -0.0032], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 1.33 (20 episode_length, Parameter containing:
# tensor([-0.0070,  0.0041], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 1.21 (20 episode_length, Parameter containing:
# tensor([-0.0206,  0.0139], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 1.13 (20 episode_length, Parameter containing:
# tensor([-0.0004,  0.0057], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 1.25 (20 episode_length, Parameter containing:
# tensor([-0.0027, -0.0066], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 1.3 (20 episode_length, Parameter containing:
# tensor([0.0064, 0.0056], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 1.24 (20 episode_length, Parameter containing:
# tensor([0.0125, 0.0012], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 1.28 (20 episode_length, Parameter containing:
# tensor([0.0034, 0.0029], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 1.26 (20 episode_length, Parameter containing:
# tensor([ 0.0018, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 1.16 (20 episode_length, Parameter containing:
# tensor([-7.3738e-04,  4.7917e-05], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 1.24 (20 episode_length, Parameter containing:
# tensor([0.0046, 0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 1.28 (20 episode_length, Parameter containing:
# tensor([0.0014, 0.0050], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 1.17 (20 episode_length, Parameter containing:
# tensor([-0.0018, -0.0024], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 1.31 (20 episode_length, Parameter containing:
# tensor([-0.0045, -0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 1.31 (20 episode_length, Parameter containing:
# tensor([ 0.0037, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 1.37 (20 episode_length, Parameter containing:
# tensor([ 0.0009, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 1.39 (20 episode_length, Parameter containing:
# tensor([ 0.0006, -0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 1.29 (20 episode_length, Parameter containing:
# tensor([-0.0031,  0.0045], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 1.26 (20 episode_length, Parameter containing:
# tensor([ 0.0010, -0.0025], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 1.46 (20 episode_length, Parameter containing:
# tensor([-0.0026, -0.0013], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 1.42 (20 episode_length, Parameter containing:
# tensor([ 0.0045, -0.0026], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 1.45 (20 episode_length, Parameter containing:
# tensor([-0.0018, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 1.27 (20 episode_length, Parameter containing:
# tensor([-0.0015,  0.0018], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 1.33 (20 episode_length, Parameter containing:
# tensor([ 1.2117e-03, -2.9552e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 1.25 (20 episode_length, Parameter containing:
# tensor([-0.0003, -0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 1.37 (20 episode_length, Parameter containing:
# tensor([-0.0015, -0.0021], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 1.28 (20 episode_length, Parameter containing:
# tensor([ 0.0004, -0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 1.37 (20 episode_length, Parameter containing:
# tensor([3.6319e-05, 6.3105e-04], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 1.4 (20 episode_length, Parameter containing:
# tensor([ 0.0002, -0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 1.39 (20 episode_length, Parameter containing:
# tensor([-1.3667e-04, -7.6956e-06], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/model/model_parameters_1.pt ...
# logger and seed 1
# /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/logging/logs_1.csv
# ------Training finished.------
# Total traning time is 7.063724267979463mins
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-0.mp4
# Episode 99 Step 2000 finished. Average episode return: 0.08 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: -0.09 (20 episode_length, Parameter containing:
# tensor([ 0.0124, -0.0159], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.05 (20 episode_length, Parameter containing:
# tensor([0.0156, 0.0022], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.17 (20 episode_length, Parameter containing:
# tensor([ 0.0155, -0.0165], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.38 (20 episode_length, Parameter containing:
# tensor([ 0.0171, -0.0267], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.22 (20 episode_length, Parameter containing:
# tensor([ 0.0006, -0.0046], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.33 (20 episode_length, Parameter containing:
# tensor([0.0083, 0.0164], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.27 (20 episode_length, Parameter containing:
# tensor([-0.0142,  0.0184], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.49 (20 episode_length, Parameter containing:
# tensor([-0.0086,  0.0287], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.61 (20 episode_length, Parameter containing:
# tensor([-0.0165,  0.0184], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-1000.mp4
# Episode 1099 Step 22000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([-0.0198,  0.0283], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.72 (20 episode_length, Parameter containing:
# tensor([-0.0336,  0.0325], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0413,  0.0029], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.82 (20 episode_length, Parameter containing:
# tensor([-0.0332,  0.0069], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-0.0205, -0.0013], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0167, -0.0065], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([-0.0231, -0.0149], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-0.0219, -0.0079], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([-0.0297, -0.0160], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.9 (20 episode_length, Parameter containing:
# tensor([-0.0244, -0.0138], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-2000.mp4
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.94 (20 episode_length, Parameter containing:
# tensor([-0.0119, -0.0030], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 1.06 (20 episode_length, Parameter containing:
# tensor([-0.0131, -0.0105], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([ 0.0017, -0.0073], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 1.02 (20 episode_length, Parameter containing:
# tensor([-0.0028, -0.0110], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 1.02 (20 episode_length, Parameter containing:
# tensor([-0.0144,  0.0041], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.95 (20 episode_length, Parameter containing:
# tensor([-0.0186,  0.0012], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 1.01 (20 episode_length, Parameter containing:
# tensor([-0.0068, -0.0086], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.99 (20 episode_length, Parameter containing:
# tensor([-0.0005, -0.0113], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 1.02 (20 episode_length, Parameter containing:
# tensor([0.0011, 0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 1.07 (20 episode_length, Parameter containing:
# tensor([ 0.0006, -0.0112], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-3000.mp4
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 1.08 (20 episode_length, Parameter containing:
# tensor([-0.0014, -0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.98 (20 episode_length, Parameter containing:
# tensor([0.0067, 0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.99 (20 episode_length, Parameter containing:
# tensor([-0.0038,  0.0057], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 1.01 (20 episode_length, Parameter containing:
# tensor([-0.0058,  0.0118], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 1.05 (20 episode_length, Parameter containing:
# tensor([0.0008, 0.0074], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 1.16 (20 episode_length, Parameter containing:
# tensor([-0.0009,  0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 1.17 (20 episode_length, Parameter containing:
# tensor([-0.0043,  0.0024], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 1.07 (20 episode_length, Parameter containing:
# tensor([-0.0056, -0.0017], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([-0.0007,  0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 1.16 (20 episode_length, Parameter containing:
# tensor([-0.0058,  0.0053], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-4000.mp4
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 1.11 (20 episode_length, Parameter containing:
# tensor([-0.0031,  0.0021], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 1.23 (20 episode_length, Parameter containing:
# tensor([-0.0015, -0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 1.24 (20 episode_length, Parameter containing:
# tensor([0.0023, 0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 1.07 (20 episode_length, Parameter containing:
# tensor([-0.0015, -0.0018], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 1.24 (20 episode_length, Parameter containing:
# tensor([-0.0024, -0.0015], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 1.18 (20 episode_length, Parameter containing:
# tensor([-0.0008,  0.0029], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 1.18 (20 episode_length, Parameter containing:
# tensor([-0.0004,  0.0036], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 1.25 (20 episode_length, Parameter containing:
# tensor([-0.0007, -0.0018], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 1.22 (20 episode_length, Parameter containing:
# tensor([-4.1825e-04,  7.8045e-06], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 1.1 (20 episode_length, Parameter containing:
# tensor([0.0002, 0.0004], requires_grad=True) logstd)
# Moviepy - Building video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4.
# Moviepy - Writing video /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/train/project-episode-5000.mp4
# Saved model to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/model/model_parameters_2.pt ...
# logger and seed 2
# /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/logging/logs_2.csv
# ------Training finished.------
# Total traning time is 7.144638802732031mins

# %% [markdown]
# **Test**: After training, run the following code to test your agents.

# %%
from algo.ppo_extension import PPOExtension
implemented_algo = 'ppo_extension'
if skip_training == False:
    training_seeds = []
    for i in range(3):
        config=setup(algo=implemented_algo, env=environment)
    
        config["seed"] = i
        training_seeds.append(i)
    
    
        if config["args"].algo_name == 'ppo_extension':
            agent=PPOExtension(config)
        #elif config["args"].algo_name == 'ddpg_extension':
        #    agent=DDPGExtension(config)
        else:
            raise Exception('Please use ppo or ddpg!')
    
        # Test the agent in the selected environment
        test(agent, environment, implemented_algo)
# Out:
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_0_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_0_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_0_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_0_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_0_ep_400.gif
# Average test reward over 500 episodes: 1.008,+- 0.6632767145015721;         Average episode length: 20.0
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_1_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_1_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_1_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_1_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_1_ep_400.gif
# Average test reward over 500 episodes: 1.266,+- 0.6776754385397187;         Average episode length: 20.0
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_2_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_2_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_2_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_2_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvMiddle/ppo_extension/video/test/_seed_2_ep_400.gif
# Average test reward over 500 episodes: 1.134,+- 0.6812077509835013;         Average episode length: 20.0

# %% [markdown]
# ## Task 2.2: Plot improved algorithm performance
#
# ### a) Display the plots:
# Display the training performance of your improved algorithm, similarly as in task 1.3
#
# ### b) Paths:
# Your plot should be plotted in the following paths if the code runs successfully:
#
# - **improved Middle**:
#   - `results/SandingEnvMiddle/ppo_extension(or ddpg_extension)/logging/figure_statistical_SandingEnvMiddle.pdf`

# %%
## Run the following code to plot PPO or DDPG's training performances
import warnings
warnings.filterwarnings('ignore')

if skip_training == False:
    
    # Uncomment the algorithm you chose 
    implemented_algo = 'ppo_extension'# 'ppo_extension' or 'ddpg_extension'
    environment = 'middle'
    
    # Loop over the three difficulty levels
    
    training_seeds = [0,1,2]
    
    config=setup(algo=implemented_algo, env=environment)
    
    config["seed"] = 0
    
    agent=PPOExtension(config)# DDPGExtension(config) or PPOExtension(config)
    
    # plot the statistical training curves with specific random seeds
    cu.plot_algorithm_training(agent.logging_dir, training_seeds, agent.env_name, implemented_algo)

# %% [markdown]
# ## Task 2.3: Comparison of Improved and Original Algorithm Performance
#
# ### a) Display the Plots
# Display the training performance of both the improved and the original algorithms.
#
# We aim to compare the training performances of the original and improved algorithms. To achieve this, we will generate the following plots, which will highlight the sample efficiency and the agent's performance throughout the training process. Below are some figures comparing the performances of DDPG and PPO:
#
# <p align="center">
#   <figure style="display: inline-block; text-align: center; margin: 10px;">
#     <img src="imgs/middle_compare_ddpg_ppo.png" alt="PPO Middle Environment" width="540"/>
#     <figcaption>PPO vs DDPG (Middle environment)</figcaption>
#   </figure>
#
# </p>
#
# **Note**: The display does not need to exactly match the figures shown above. However, the code should generate a figure to compare the original algorithm with the improved algorithm.
#
# ### b) Paths
# If the code runs successfully, your plot should be saved to the following paths:
#
# - **Original vs Improved (Middle Environment)**:
#   - `results/SandingEnvMiddle/compare_ddpg_ddpg_extension.pdf`
#   - or
#   - `results/SandingEnvMiddle/compare_ppo_ppo_extension.pdf`

# %%
## Run the following code to draw the comparison plots of PPO and DDPG's training performances
import warnings
warnings.filterwarnings('ignore')

environment = 'middle'

if skip_training == False:
    orgin_alo_name = 'ppo'# 'ddpg' or 'ppo'
    improved_alo_name =  'ppo_extension'# 'ddpg_extension' or 'ppo_extension'
    
    config=setup(algo=orgin_alo_name, env=environment)
    origin_agent = PPOAgent(config)# DDPGAgent(config) or PPOAgent(config)
    
    config=setup(algo=improved_alo_name, env=environment)
    improved_agent =  PPOExtension(config)# DDPGExtension(config) or PPOExtension(config)
    
    # make the comparison plot
    cu.compare_algorithm_training(origin_agent, improved_agent, seeds=[0,1,2])

# %% [markdown]
# The following cells are used for grading

# %%
# %%capture --no-stdout
"TEST"

# %%
# %%capture --no-stdout
"TEST"

# %%
# %%capture --no-stdout
"TEST"

# %%
# %%capture --no-stdout
"TEST"

# %% [markdown]
# <a id='Q1'></a>
# <div class="alert alert-warning">
#     <h3><b>Student Question 1</b> (30 points)</h3>
#
#     1. Answer the questions regarding how you extended PPO/DDPG. ONLY choose the question group related to your extension.
#
#     2. Each question will tell you the maximum number of answers you can select, however the number of correct answers can be lower.
#
#     3. Please do not select more answers than the maximum number as that will reduce your points to zero.
#
#     4. You get full points for selecting the correct answers in every question.
#
#     5. You get partial points if you select a mix of correct and wrong answers.
#
#     6. Make sure to submit your answers.
#
#     7. For LNSS questions you may seek help from https://openreview.net/forum?id=EGfYnTyEGv
#
# </div>

# %%
from IPython.display import display, Markdown
import ipywidgets as widgets
import pickle


# Define the questions for each topic with the exact content you provided
ppo_questions = [
    {
        'question_id': 'PPO_Q1',
        'question': 'What problem does Dual-Clip PPO aim to address? (Select a maximum of 3 options)',
        'options': {
            'A': 'Reducing computational complexity',
            'B': 'Managing large policy deviations',
            'C': 'Enhancing exploration',
            'D': 'Bounding the objective when advantage is less than zero'
        },
    },
    {
        'question_id': 'PPO_Q2',
        'question': 'How does Dual-Clip PPO differ from standard PPO in its clipping strategy? (Select a maximum of 3 options)',
        'options': {
            'A': 'It uses a single clipping parameter',
            'B': 'It introduces a second clipping for negative advantages',
            'C': 'The range of ratio in PPO is $(1- \\epsilon, \\infty)$, while in Dual-PPO is $(1- \\epsilon, c)$ when advantage is less than zero',
            'D': 'It clips both state and action spaces'
        },
    }
]

sil_questions = [
    {
        'question_id': 'SIL_Q1',
        'question': 'Which of the following describes how SIL selects experiences for learning? (Select a maximum of 3 options)',
        'options': {
            'A': 'SIL uses experiences that maximize the entropy of the policy.',
            'B': 'SIL uses experiences where the past returns exceed the agent\'s current value estimate.',
            'C': 'SIL prioritizes experiences based on clipped advantage.',
            'D': 'SIL selects random experiences from the replay buffer.'
        },
    },
    {
        'question_id': 'SIL_Q2',
        'question': 'What are the potential downsides of using SIL? (Select a maximum of 3 options)',
        'options': {
            'A': 'It may lead to overfitting on suboptimal past experiences.',
            'B': 'It can significantly increase the computational load.',
            'C': 'It requires a large amount of expert data to start learning.',
            'D': 'Some off-policy methods may not benefit much from SIL.'
        },
    }
]

ddpg_lnss_questions = [
    {
        'question_id': 'DDPG_Q1',
        'question': 'What are the correct descriptions of LNSS: (Select a maximum of 5 options)',
        'options': {
            'A': 'The surrogate reward actually is a weighted average of discounted N-step return;',
            'B': (
                'Given following equations\n'
                '$$G_k = \\sum_{t=k}^{k+N-1} \\gamma^{t-k} r_t$$,\n'
                '$$ r\'_k = \\frac{\\sum_{t=k}^{k+N-1} \\gamma^{t-k} r_t}{\\sum_{n=0}^{N-1} \\gamma^n}$$,\n'
                '$$ r\'_k = \\frac{\\gamma - 1}{\\gamma^N - 1} \\sum_{t=k}^{k+N-1} \\gamma^{t-k} r_t.$$ \n'
                'These three equations describe different accumulated reward for making a surrogate reward.'
            ),
            'C': 'LNSS can reduce the estimated Q-value variance ;',
            'D': 'Use a larger $N$ hyperparameter for calculating the surrogate reward can help reduce the upper bound of estimated Q-value variance ;',
            'E': (
                'Given the surrogate reward $r\'_t$ defined in Eq.7, the accumulated reward $G\'_k = \\sum_{t=k}^{k+N-1} \\gamma^{t-k} r\'_t$, upon learning convergence, '
                '$G\'_k$ is a biased estimate of $G_k$ in Eq.4'
            ),
            'F': (
                'If we assume that the given policy $\\pi$ results in the same expectation of stage reward, i.e., $\\mathbb{E}^{\\pi}[r_k] = \\mathbb{E}^{\\pi}[r\'_k]$ for all $k$. '
                'then the $Q^{\\pi}$ of using the original reward and $Q^{\\pi}$ of using LNSS are the same. '
            ),
            'G': (
                'If $\\pi$ refers to policy $\\pi_j$ for $j \\to \\infty$ (meaning that episode horizon is infinite). In this case, we can consider '
                '$Q^{\\pi} = Q^{\\pi_{\\infty}}, \\mathbf{Q}^{\\bar{\\pi}} = \\mathbf{Q}^{\\bar{\\pi}_{\\infty}}$ but  $Q^{\\pi_{\\infty}} \\neq \\mathbf{Q}^{\\bar{\\pi}_{\\infty}}$.\n'
                'This is because using different rewards, the target policy will be different during policy improvement so that it results in different $Q$ values.'
            ),
            
            
        },
    },
    {
        'question_id': 'DDPG_Q2',
        'question': '“n-step” RL and LNSS: (Select a maximum of 4 options)',
        'options': {
            'A': (
                'LNSS can have unbiased estimation of Q-value, but “n-step” RL like n-step DDPG or n-step D4PG with deterministic policy may not. '
            ),
            'B': (
                'Off-policy n-step methods such as TD($\\lambda$) and Q($\\sigma$) are shown to decrease the estimation bias also increases the variance. '
                'As LNSS aims to, and is shown to, reduce variance without sacrificing bias.'
            ),
            'C': 'Importance sampling is required when applying n-step bootstrapping to calculate the TD target when the policy is non-deterministic   ',
            'D': 'If we use LNSS, we should better not to use “n-step” RL ',
            'E': (
                'LNSS theoretically reduces the upper bound of variance according to Theorem 1. Furthermore, this bound linearly decreases as N increases.  '
            ),
            'F': 'Using the LNSS surrogate reward $r’_k$ may introduce additional estimation bias ',
            'G': (
                'Off-policy n-step methods such as TD($\\lambda$) and Q($\\sigma$) are shown to increase the estimation bias also increases the variance. '
                'As LNSS aims to, and is shown to, reduce variance without sacrificing bias. '
            ),
            'H': 'LNSS is more like automatically design a dense reward but it is not for “n-step” RL.',

            'I': '''For classical Q learning, we can directly use this equation to calculate the n-step TD target to update the Q function
$$
\\sum_{t=k}^{k+n-1} \\gamma^{t-k} r_t + \\gamma^n Q^{\\pi}(s_{k+n}, a_{k+n})
$$.
'''
        },
    },
    {
        'question_id': 'DDPG_Q3',
        'question': 'What are the correct descriptions of LNSS implementations: (Select a maximum of 3 options)',
        'options': {
            'A': 'We can randomly define N as we want as long as $N \\leq T$ where $T$ is the task horizon.',
            'B': (
                'Because LNSS needs to maintain another additional buffer to store the reward, so it doubles the memory for saving data during training. '
            ),
            'C': (
                'In some cases, LNSS will not relabel each interaction by recalculate and relabel reward of the transition tuple $(s, a, r, s’)$  ->  $(s, a, r_{LNSS}, s’)$.\n'
                'For example,  $k+N-1$ exceed the episode horizon then we will not recalculate the reward.'
            ),
            'D': (
                'If $k + N - 1 \\geq T$, which signifies a sufficient number of experience samples to compute LNSS surrogate reward $r\'$ with full $N$ steps, then\n'
                '$$ r\' = \\left( \\sum_{t=k}^{k+N-1} \\gamma^{t-k} r_t \\right) * \\frac{\\gamma - 1}{\\gamma^N - 1}. $$  '
            ),
            'E': 'Compared with classical off-policy RLs (DDPG, TD3, SAC, etc, ...) replay buffer, LNSS needs to maintain another additional buffer to store experience.',
            'F': (
                'In LNSS, we should not only store the re-calculated dense reward, but also need to keep the original reward in experience replay buffer.'
            )
        },
    }
]

# Function to create question widgets with left-aligned options
def create_question_widget(question_data):
    question_id = question_data['question_id']
    question_text = question_data['question']
    options = question_data['options']
    
    # Display the question
    display(Markdown(f"**{question_id}. {question_text}**"))
    
    # Create checkboxes for options
    option_widgets = []
    for key, value in options.items():
        if value.strip() == '':
            continue  # Skip empty options
        cb = widgets.Checkbox(value=False, layout=widgets.Layout(width='auto'))
        # Use HTMLMath widget to display LaTeX equations
        label_html = widgets.HTMLMath(value=f"<b>{key})</b> {value}", layout=widgets.Layout(width='auto'))
        # Combine checkbox and label, align items to the start (left)
        hb = widgets.HBox([cb, label_html], layout=widgets.Layout(align_items='flex-start'))
        option_widgets.append({'option_letter': key, 'checkbox': cb, 'widget': hb})
    
    # Arrange options vertically, align items to the start (left)
    options_box = widgets.VBox([item['widget'] for item in option_widgets], layout=widgets.Layout(align_items='flex-start'))
    display(options_box)
    
    # Return the list of option widgets so we can retrieve the values later
    return {'question_id': question_id, 'option_widgets': option_widgets}

# Create topic selector
topic_selector = widgets.SelectMultiple(
    options=['PPO', 'SIL', 'DDPG LNSS'],
    description='Select Topic(s):',
    disabled=False
)

proceed_button = widgets.Button(description="Proceed")
display(topic_selector, proceed_button)

display_area = widgets.Output()
display(display_area)

# Global variable to store all question widgets
all_question_widgets = []

# Function to handle proceed button click
def on_proceed_button_clicked(b):
    # Clear previous output
    display_area.clear_output()
    selected_topics = topic_selector.value
    # Clear previous question widgets
    global all_question_widgets
    all_question_widgets = []
    with display_area:
        for topic in selected_topics:
            if topic == 'PPO':
                for question_data in ppo_questions:
                    question_widget = create_question_widget(question_data)
                    all_question_widgets.append(question_widget)
            elif topic == 'SIL':
                for question_data in sil_questions:
                    question_widget = create_question_widget(question_data)
                    all_question_widgets.append(question_widget)
            elif topic == 'DDPG LNSS':
                for question_data in ddpg_lnss_questions:
                    question_widget = create_question_widget(question_data)
                    all_question_widgets.append(question_widget)
        # Display the submit button
        display(submit_button, output)

proceed_button.on_click(on_proceed_button_clicked)

# Create submit button and output area
submit_button = widgets.Button(description="Submit")
output = widgets.Output()
submission = {}
# Function to handle submit button click
def on_submit_button_clicked(b):
    with output:
        # Clear previous output
        output.clear_output()
        # Collect the answers
        print("Your submission:")
        
        # Create a mapping from question_id to topic
        question_id_to_topic = {}
        # Build the mapping
        for topic in ['PPO', 'SIL', 'DDPG LNSS']:
            if topic == 'PPO':
                questions = ppo_questions
            elif topic == 'SIL':
                questions = sil_questions
            elif topic == 'DDPG LNSS':
                questions = ddpg_lnss_questions
            for question_data in questions:
                question_id = question_data['question_id']
                question_id_to_topic[question_id] = topic
        
        # Prepare the submission variable
        global submission  # Declare submission as global to modify it inside the function
        submission = {}
        # Now process the submissions
        for question in all_question_widgets:
            question_id = question['question_id']
            option_widgets = question['option_widgets']
            selected_options = []
            for item in option_widgets:
                if item['checkbox'].value:
                    selected_options.append(item['option_letter'])
            # Get the topic from the mapping
            question_topic = question_id_to_topic.get(question_id, 'Unknown Topic')
            # Store the submission data
            
            submission[question_id] = {
                'selected_options': selected_options
            }
            # Print the submission for each question including the topic
            print(f"{question_topic} - {question_id}: {''.join(selected_options)}")
        
        # After processing all submissions, print the submission variable
        print("\nSubmission variable contents:")
        print(submission)
        with open('results/answers.pkl', 'wb') as f:
            pickle.dump(submission, f)


# Assign the event handler to the submit button
submit_button.on_click(on_submit_button_clicked)
# Out:
# SelectMultiple(description='Select Topic(s):', options=('PPO', 'SIL', 'DDPG LNSS'), value=())
# Button(description='Proceed', style=ButtonStyle())
# Output()

# %% [markdown]
# The following cells are used for grading, please do not remove them.

# %% [markdown]
# <a id='T3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 3</b> (+20 points) </h3>
#     This task gives bonus points to the project works that get highest performance.
#
#     1. Your projects shall be evaluated based on their performance in the difficult environment.
#
#     2. Among all submissions, the best performing project (100% ranked) will receive 20 bonus points, 95% ranked or above will get 10 bonus points. (+20 points)
#
#     3. Run the cell below to do the evaluation, make sure all the generated files are included when you submit your work.
# </div>

# %% [markdown]
# ## Task 3.1: Evaluate Your Improved Algorithm with difficult environment
#
#
# ### a) Training
# - **Random Seeds**: Train your algorithm using three distinct random seeds [0,1,2] to ensure robustness and repeatability.
#
# ### b) Evaluation
# - **Environment**: Evaluate your algorithm exclusively in the **difficult-level difficulty environment** to focus your improvements.
#
# ### c) Code Compatibility
# - Ensure that your code is **fully compatible** with all existing functions in other files, maintaining the integrity of the overall project structure.
#
# ---

# %%
#from algo.ddpg_agent import DDPGAgent
from algo.ppo_agent import PPOAgent
#from algo.ddpg_extension import DDPGExtension
from algo.ppo_extension import PPOExtension
# implement your improved algorithm either in algo/ddpg_extension.py or algo/ppo_extension.py

implemented_algo = 'ppo_extension'# choose 'ppo_extension' or 'ddpg_extension'
environment = 'difficult'

training_seeds = []
#skip_training = False
if not skip_training:
    for i in range(3):
        config=setup(algo=implemented_algo, env=environment)

        config["seed"] = i
        training_seeds.append(i)


        if config["args"].algo_name == 'ppo':
            agent=PPOAgent(config)
        #elif config["args"].algo_name == 'ddpg':
        #    agent=DDPGAgent(config)
        elif config["args"].algo_name == 'ppo_extension':
            agent=PPOExtension(config)
        #elif config["args"].algo_name == 'ddpg_extension':
        #    agent=DDPGExtension(config)
        else:
            raise Exception('Please use ppo or ddpg!')

        # Train the agent using selected algorithm    
        agent.train()
# Out:
# /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment SandingEnvDifficult already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /opt/software/lib/python3.10/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Episode 99 Step 2000 finished. Average episode return: 0.35 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.26 (20 episode_length, Parameter containing:
# tensor([-0.0131, -0.0089], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.08 (20 episode_length, Parameter containing:
# tensor([-0.0129, -0.0194], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.37 (20 episode_length, Parameter containing:
# tensor([-0.0060,  0.0001], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.25 (20 episode_length, Parameter containing:
# tensor([-0.0026,  0.0241], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.38 (20 episode_length, Parameter containing:
# tensor([-0.0149,  0.0187], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.24 (20 episode_length, Parameter containing:
# tensor([-0.0100,  0.0053], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.4 (20 episode_length, Parameter containing:
# tensor([-0.0135,  0.0094], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.47 (20 episode_length, Parameter containing:
# tensor([-0.0081,  0.0251], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.42 (20 episode_length, Parameter containing:
# tensor([-0.0016,  0.0387], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1099 Step 22000 finished. Average episode return: 0.38 (20 episode_length, Parameter containing:
# tensor([-0.0115,  0.0242], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.48 (20 episode_length, Parameter containing:
# tensor([-0.0022,  0.0190], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.43 (20 episode_length, Parameter containing:
# tensor([1.8327e-05, 1.7713e-02], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.45 (20 episode_length, Parameter containing:
# tensor([0.0041, 0.0263], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.34 (20 episode_length, Parameter containing:
# tensor([-0.0032,  0.0144], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.49 (20 episode_length, Parameter containing:
# tensor([-0.0120, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.44 (20 episode_length, Parameter containing:
# tensor([-0.0162, -0.0049], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.55 (20 episode_length, Parameter containing:
# tensor([-0.0055, -0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.4 (20 episode_length, Parameter containing:
# tensor([-0.0008, -0.0045], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.57 (20 episode_length, Parameter containing:
# tensor([-0.0027, -0.0129], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.45 (20 episode_length, Parameter containing:
# tensor([-0.0020, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.49 (20 episode_length, Parameter containing:
# tensor([-0.0058, -0.0079], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.54 (20 episode_length, Parameter containing:
# tensor([-0.0134, -0.0125], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.49 (20 episode_length, Parameter containing:
# tensor([-0.0066,  0.0014], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([0.0036, 0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([0.0042, 0.0042], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 0.48 (20 episode_length, Parameter containing:
# tensor([ 0.0032, -0.0043], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.54 (20 episode_length, Parameter containing:
# tensor([-0.0030, -0.0019], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.46 (20 episode_length, Parameter containing:
# tensor([-0.0058,  0.0027], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0032,  0.0065], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.69 (20 episode_length, Parameter containing:
# tensor([-0.0016,  0.0027], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.54 (20 episode_length, Parameter containing:
# tensor([ 0.0029, -0.0005], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.45 (20 episode_length, Parameter containing:
# tensor([-0.0044, -0.0025], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.55 (20 episode_length, Parameter containing:
# tensor([ 0.0020, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([-0.0025, -0.0086], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.63 (20 episode_length, Parameter containing:
# tensor([-0.0021, -0.0056], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 0.54 (20 episode_length, Parameter containing:
# tensor([-0.0010, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([ 0.0023, -0.0042], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 0.58 (20 episode_length, Parameter containing:
# tensor([0.0006, 0.0005], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 0.58 (20 episode_length, Parameter containing:
# tensor([ 0.0017, -0.0026], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([ 0.0003, -0.0019], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([ 2.8913e-03, -4.0986e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([-0.0001,  0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.58 (20 episode_length, Parameter containing:
# tensor([0.0008, 0.0011], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([5.2289e-04, 1.8145e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 0.57 (20 episode_length, Parameter containing:
# tensor([-0.0023, -0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 0.4 (20 episode_length, Parameter containing:
# tensor([-7.5030e-04,  9.9223e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([ 0.0009, -0.0004], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 0.57 (20 episode_length, Parameter containing:
# tensor([ 0.0004, -0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 0.64 (20 episode_length, Parameter containing:
# tensor([0.0002, 0.0002], requires_grad=True) logstd)
# Saved model to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/model/model_parameters_0.pt ...
# logger and seed 0
# /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/logging/logs_0.csv
# ------Training finished.------
# Total traning time is 17.367922099431357mins
# Episode 99 Step 2000 finished. Average episode return: 0.2 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.31 (20 episode_length, Parameter containing:
# tensor([0.0196, 0.0137], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.26 (20 episode_length, Parameter containing:
# tensor([0.0269, 0.0033], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.26 (20 episode_length, Parameter containing:
# tensor([ 0.0484, -0.0046], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.53 (20 episode_length, Parameter containing:
# tensor([0.0545, 0.0025], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.33 (20 episode_length, Parameter containing:
# tensor([ 0.0458, -0.0134], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([ 0.0412, -0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.57 (20 episode_length, Parameter containing:
# tensor([ 0.0319, -0.0051], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.53 (20 episode_length, Parameter containing:
# tensor([0.0187, 0.0027], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.53 (20 episode_length, Parameter containing:
# tensor([0.0203, 0.0157], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1099 Step 22000 finished. Average episode return: 0.51 (20 episode_length, Parameter containing:
# tensor([0.0308, 0.0272], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.77 (20 episode_length, Parameter containing:
# tensor([0.0272, 0.0265], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.63 (20 episode_length, Parameter containing:
# tensor([0.0150, 0.0163], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([0.0173, 0.0076], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([ 0.0057, -0.0030], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.59 (20 episode_length, Parameter containing:
# tensor([0.0046, 0.0037], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([0.0023, 0.0006], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0007,  0.0114], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([0.0032, 0.0088], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 0.59 (20 episode_length, Parameter containing:
# tensor([0.0068, 0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([0.0123, 0.0097], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([0.0184, 0.0036], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.79 (20 episode_length, Parameter containing:
# tensor([0.0033, 0.0087], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.88 (20 episode_length, Parameter containing:
# tensor([-0.0094,  0.0071], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([-0.0032, -0.0163], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.92 (20 episode_length, Parameter containing:
# tensor([-0.0067, -0.0068], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([-0.0016, -0.0046], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 0.94 (20 episode_length, Parameter containing:
# tensor([0.0023, 0.0069], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.94 (20 episode_length, Parameter containing:
# tensor([0.0015, 0.0053], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.93 (20 episode_length, Parameter containing:
# tensor([-0.0020,  0.0061], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.98 (20 episode_length, Parameter containing:
# tensor([-0.0091,  0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.99 (20 episode_length, Parameter containing:
# tensor([-0.0110,  0.0072], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([-0.0098,  0.0034], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 0.92 (20 episode_length, Parameter containing:
# tensor([-0.0064,  0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 1.07 (20 episode_length, Parameter containing:
# tensor([-0.0049, -0.0060], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 1.01 (20 episode_length, Parameter containing:
# tensor([ 0.0030, -0.0009], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 1.31 (20 episode_length, Parameter containing:
# tensor([-0.0001,  0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0053,  0.0086], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 1.11 (20 episode_length, Parameter containing:
# tensor([0.0008, 0.0004], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 1.12 (20 episode_length, Parameter containing:
# tensor([ 0.0043, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 1.18 (20 episode_length, Parameter containing:
# tensor([0.0024, 0.0054], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.86 (20 episode_length, Parameter containing:
# tensor([-0.0006,  0.0009], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.92 (20 episode_length, Parameter containing:
# tensor([0.0006, 0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.97 (20 episode_length, Parameter containing:
# tensor([0.0013, 0.0012], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 1.06 (20 episode_length, Parameter containing:
# tensor([-0.0006,  0.0018], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 1.27 (20 episode_length, Parameter containing:
# tensor([-0.0016,  0.0018], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 1.21 (20 episode_length, Parameter containing:
# tensor([-0.0002, -0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 1.2 (20 episode_length, Parameter containing:
# tensor([-0.0004, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 1.1 (20 episode_length, Parameter containing:
# tensor([-0.0003, -0.0002], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 1.05 (20 episode_length, Parameter containing:
# tensor([ 2.0328e-05, -2.7076e-04], requires_grad=True) logstd)
# Saved model to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/model/model_parameters_1.pt ...
# logger and seed 1
# /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/logging/logs_1.csv
# ------Training finished.------
# Total traning time is 17.5800766573598mins
# Episode 99 Step 2000 finished. Average episode return: 0.1 (20 episode_length, Parameter containing:
# tensor([0., 0.], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 199 Step 4000 finished. Average episode return: 0.11 (20 episode_length, Parameter containing:
# tensor([0.0163, 0.0069], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 299 Step 6000 finished. Average episode return: 0.19 (20 episode_length, Parameter containing:
# tensor([0.0413, 0.0212], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 399 Step 8000 finished. Average episode return: 0.32 (20 episode_length, Parameter containing:
# tensor([0.0456, 0.0127], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 499 Step 10000 finished. Average episode return: 0.31 (20 episode_length, Parameter containing:
# tensor([0.0425, 0.0060], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 599 Step 12000 finished. Average episode return: 0.52 (20 episode_length, Parameter containing:
# tensor([0.0761, 0.0005], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 699 Step 14000 finished. Average episode return: 0.28 (20 episode_length, Parameter containing:
# tensor([ 0.0757, -0.0134], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 799 Step 16000 finished. Average episode return: 0.43 (20 episode_length, Parameter containing:
# tensor([ 0.0825, -0.0107], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 899 Step 18000 finished. Average episode return: 0.48 (20 episode_length, Parameter containing:
# tensor([0.0651, 0.0073], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 999 Step 20000 finished. Average episode return: 0.39 (20 episode_length, Parameter containing:
# tensor([0.0467, 0.0083], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1099 Step 22000 finished. Average episode return: 0.5 (20 episode_length, Parameter containing:
# tensor([0.0253, 0.0028], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1199 Step 24000 finished. Average episode return: 0.48 (20 episode_length, Parameter containing:
# tensor([0.0283, 0.0046], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1299 Step 26000 finished. Average episode return: 0.48 (20 episode_length, Parameter containing:
# tensor([4.1703e-02, 3.3139e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1399 Step 28000 finished. Average episode return: 0.55 (20 episode_length, Parameter containing:
# tensor([2.7906e-02, 2.2362e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1499 Step 30000 finished. Average episode return: 0.6 (20 episode_length, Parameter containing:
# tensor([ 0.0105, -0.0023], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1599 Step 32000 finished. Average episode return: 0.66 (20 episode_length, Parameter containing:
# tensor([ 0.0088, -0.0115], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1699 Step 34000 finished. Average episode return: 0.48 (20 episode_length, Parameter containing:
# tensor([ 0.0084, -0.0104], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1799 Step 36000 finished. Average episode return: 0.65 (20 episode_length, Parameter containing:
# tensor([ 0.0017, -0.0050], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1899 Step 38000 finished. Average episode return: 0.71 (20 episode_length, Parameter containing:
# tensor([ 0.0012, -0.0115], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 1999 Step 40000 finished. Average episode return: 1.01 (20 episode_length, Parameter containing:
# tensor([-0.0093, -0.0131], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2099 Step 42000 finished. Average episode return: 0.67 (20 episode_length, Parameter containing:
# tensor([-0.0021, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2199 Step 44000 finished. Average episode return: 0.73 (20 episode_length, Parameter containing:
# tensor([-0.0056, -0.0113], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2299 Step 46000 finished. Average episode return: 0.72 (20 episode_length, Parameter containing:
# tensor([-0.0069, -0.0044], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2399 Step 48000 finished. Average episode return: 0.68 (20 episode_length, Parameter containing:
# tensor([-0.0140, -0.0109], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2499 Step 50000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-1.2225e-02,  1.9883e-05], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2599 Step 52000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0151, -0.0071], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2699 Step 54000 finished. Average episode return: 0.76 (20 episode_length, Parameter containing:
# tensor([-0.0103,  0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2799 Step 56000 finished. Average episode return: 1.0 (20 episode_length, Parameter containing:
# tensor([-0.0057, -0.0047], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2899 Step 58000 finished. Average episode return: 0.83 (20 episode_length, Parameter containing:
# tensor([-0.0124, -0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 2999 Step 60000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([ 0.0033, -0.0118], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3099 Step 62000 finished. Average episode return: 0.78 (20 episode_length, Parameter containing:
# tensor([ 0.0106, -0.0122], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3199 Step 64000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([ 0.0073, -0.0089], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3299 Step 66000 finished. Average episode return: 0.84 (20 episode_length, Parameter containing:
# tensor([-0.0008, -0.0137], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3399 Step 68000 finished. Average episode return: 1.05 (20 episode_length, Parameter containing:
# tensor([-0.0046, -0.0059], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3499 Step 70000 finished. Average episode return: 0.74 (20 episode_length, Parameter containing:
# tensor([-0.0030, -0.0050], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3599 Step 72000 finished. Average episode return: 0.8 (20 episode_length, Parameter containing:
# tensor([-0.0054, -0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3699 Step 74000 finished. Average episode return: 0.97 (20 episode_length, Parameter containing:
# tensor([-0.0013, -0.0016], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3799 Step 76000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([-0.0038, -0.0004], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3899 Step 78000 finished. Average episode return: 1.01 (20 episode_length, Parameter containing:
# tensor([-0.0057, -0.0020], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 3999 Step 80000 finished. Average episode return: 0.88 (20 episode_length, Parameter containing:
# tensor([-0.0028, -0.0005], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4099 Step 82000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([-0.0003, -0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4199 Step 84000 finished. Average episode return: 0.97 (20 episode_length, Parameter containing:
# tensor([ 0.0008, -0.0024], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4299 Step 86000 finished. Average episode return: 0.94 (20 episode_length, Parameter containing:
# tensor([-0.0002,  0.0007], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4399 Step 88000 finished. Average episode return: 0.87 (20 episode_length, Parameter containing:
# tensor([0.0020, 0.0014], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4499 Step 90000 finished. Average episode return: 1.02 (20 episode_length, Parameter containing:
# tensor([-0.0009,  0.0017], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4599 Step 92000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([-0.0007,  0.0003], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4699 Step 94000 finished. Average episode return: 1.22 (20 episode_length, Parameter containing:
# tensor([-0.0010, -0.0010], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4799 Step 96000 finished. Average episode return: 1.03 (20 episode_length, Parameter containing:
# tensor([-0.0010,  0.0012], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4899 Step 98000 finished. Average episode return: 1.06 (20 episode_length, Parameter containing:
# tensor([0.0005, 0.0008], requires_grad=True) logstd)
# Updating the policy...
# Updating finished!
# Episode 4999 Step 100000 finished. Average episode return: 0.89 (20 episode_length, Parameter containing:
# tensor([0.0003, 0.0001], requires_grad=True) logstd)
# Saved model to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/model/model_parameters_2.pt ...
# logger and seed 2
# /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/logging/logs_2.csv
# ------Training finished.------
# Total traning time is 17.812831926345826mins

# %% [markdown]
# **Test**: After training, run the following code to test your agents.

# %%
import pickle

if skip_training == False:
    training_seeds = []
    difficult_test_returns = [] 
    for i in range(3):
        config=setup(algo=implemented_algo, env=environment)

        config["seed"] = i
        training_seeds.append(i)


        if config["args"].algo_name == 'ppo_extension':
            agent=PPOExtension(config)
        #elif config["args"].algo_name == 'ddpg_extension':
        #    agent=DDPGExtension(config)
        else:
            raise Exception('Please use ppo or ddpg!')

        # Test the agent in the selected environment
        difficult_test_returns.append(np.mean(test(agent, environment, implemented_algo))/agent.cfg.test_episodes)

    with open('results/competition_returns.pkl', 'wb') as f:
        pickle.dump(difficult_test_returns, f)
# Out:
# Testing...
# /opt/software/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:300: UserWarning: WARN: RGB-array rendering should return a numpy array, got <class 'list'>
#   logger.warn(
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_0_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_0_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_0_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_0_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_0_ep_400.gif
# Average test reward over 500 episodes: 0.53,+- 0.6790434448545983;         Average episode length: 20.0
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_1_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_1_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_1_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_1_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_1_ep_400.gif
# Average test reward over 500 episodes: 1.094,+- 1.014477205263874;         Average episode length: 20.0
# Testing...
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_2_ep_0.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_2_ep_100.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_2_ep_200.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_2_ep_300.gif
# Saved GIF to /notebooks/rl2024/project/results/SandingEnvDifficult/ppo_extension/video/test/_seed_2_ep_400.gif
# Average test reward over 500 episodes: 1.14,+- 0.986103442849684;         Average episode length: 20.0

# %% [markdown]
# Make sure the "competition_returns.pkl" file is saved in your results directory. We will use this file to compare performances for the competition and we will retest the best performing agents.

# %% [markdown]
# ## Task 3.2: Plot the Improved Algorithm's Performance
#
# #### Display the Plots
# Display the training performance of your improved algorithm, similar to what was done in Task 2.2.
#
# #### Paths
# If the code runs successfully, your plot should be saved to the following paths:
#
# - **Improved Difficult**:
#   - `results/SandingEnvDifficult/ppo_extension/logging/figure_statistical_SandingEnvDifficult.pdf`
#
#   or
#
#   - `results/SandingEnvDifficult/ddpg_extension/logging/figure_statistical_SandingEnvDifficult.pdf`

# %%
## Run the following code to plot PPO or DDPG's training performances
import warnings
warnings.filterwarnings('ignore')
if skip_training == False:
    # Uncomment the algorithm you chose 
    implemented_algo ='ppo_extension'# 'ppo_extension' or 'ddpg_extension'
    environment = 'difficult'
    
    # Loop over the three difficulty levels
    
    training_seeds = [0,1,2]
    
    config=setup(algo=implemented_algo, env=environment)
    
    config["seed"] = 0
    
    agent=PPOExtension(config)# DDPGExtension(config) or PPOExtension(config)
    
    # plot the statistical training curves with specific random seeds
    cu.plot_algorithm_training(agent.logging_dir, training_seeds, agent.env_name, implemented_algo)

# %% [markdown]
# ## Task 3.3: Plot improved algorithm's and original's comparison performance
#
# ### Display the plots:
# Display the training performance of your improvement algorithm, similarly as in task 2.3
#
# ### Paths:
# Your plot should be plotted in the following paths if the code runs successfully:
#
# - **Original vs Improved (difficult environment)**:
#   - `results/SandingEnvDifficult/compare_ddpg_ddpg_extension.pdf`
#   - or
#   - `results/SandingEnvDifficult/compare_ppo_ppo_extension.pdf`

# %%
## Run the following code to draw the comparison plots of PPO and DDPG's training performances
import warnings
warnings.filterwarnings('ignore')

if skip_training == False:
    environment = 'difficult'

    orgin_algo_name = 'ppo'# 'ddpg' or 'ppo'
    improved_alo_name ='ppo_extension' # 'ddpg_extension' or 'ppo_extension'

    config=setup(algo=orgin_algo_name, env=environment)
    origin_agent = PPOAgent(config)# DDPGAgent(config) or PPOAgent(config)

    config=setup(algo=improved_alo_name, env=environment)
    improved_agent = PPOExtension(config)# DDPGExtension(config) or PPOExtension(config)

    # make the comparison plot
    cu.compare_algorithm_training(origin_agent, improved_agent, seeds=[0,1,2])

# %%
# Make sure that skip training is set to True before submission
assert skip_training == True
assert algorithm_implemented in ['ppo', 'ddpg']

# %% [markdown]
#  ---
# ## 9 Submitting <a id='9.'></a>
# Ensure that all tasks and questions are answered, and that the necessary plots are saved in the appropriate locations. Below is a list of the relevant plots and files that need to be submitted for the project work:
#
# ### 1. Model Weights
# For each algorithm, you should have saved three model weights in the corresponding paths:
#
# `'results/(environment name)/(algorithm name)/model/model_parameters_(seed number).pt'`
#
# **Examples:**
# - For a DDPG agent trained with seed number 0 in the middle-level sanding environment:
#   - `'results/SandingEnvMiddle/ddpg/model/model_parameters_0.pt'`
#
# **Submission Checklist:**
# Ensure that each algorithm (ddpg, ppo, ddpg_extension, ppo_extension) has three sets of model weights (model_parameters_0, model_parameters_1, model_parameters_2) saved in the above paths.
#
# ### 2. Individual Algorithm Plots
#
# You need to check that you have plotted the average training performances and the comparison plots for each algorithm. For submission, ensure the following figures are included:
#
# #### Task 1.3:
#
# - **PPO Easy**:
#   - `results/SandingEnvMiddle/PPO/logging/figure_statistical_SandingEnvEasy.pdf`
# - **PPO Middle**:
#   - `results/SandingEnvMiddle/PPO/logging/figure_statistical_SandingEnvMiddle.pdf`
#
#   or
#
# - **DDPG Easy**:
#   - `results/SandingEnvMiddle/DDPG/logging/figure_statistical_SandingEnvEasy.pdf`
# - **DDPG Middle**:
#   - `results/SandingEnvMiddle/DDPG/logging/figure_statistical_SandingEnvMiddle.pdf`
#
#
# #### Task 2.3:
#
# - **Improved agent for Middle-level environment**:
#   - `results/SandingEnvMiddle/ppo_extension(or ddpg_extension)/logging/figure_statistical_SandingEnvMiddle.pdf`
#
# #### Task 2.4:
#
# - **Original vs Improved (Middle-level Environment)**:
#   - `results/SandingEnvMiddle/compare_ddpg_ddpg_extension.pdf`
#   - or
#   - `results/SandingEnvMiddle/compare_ppo_ppo_extension.pdf`
#
# #### Task 3.3:
#
# - **Improved Difficult-level environment**:
#   - `results/SandingEnvDifficult/ppo_extension(or ddpg_extension)/logging/figure_statistical_SandingEnvMiddle.pdf`
#
# #### Task 3.4:
#
# - **Original vs Improved (Difficult-level Environment)**:
#   - `results/SandingEnvDifficult/compare_ddpg_ddpg_extension.pdf`
#   - or
#   - `results/SandingEnvDifficult/compare_ppo_ppo_extension.pdf`
#
# ### 3. Student question 1 answers
#   Ensure that you have saved your answers to the student question 1 in the file:
#     `results/answers.pkl`
#
# ### 4. Competition results
#   The returns of the extension agent on the difficult enviroment should be saved in the file:
#     `results/competition_returns.pkl`

# %% [markdown]
# ## 10. Feedback <a id='10.'></a>
#
# In order to help the staff of the course as well as the forthcoming students, it would be great if you could answer the following questions in your submission:

# %% [markdown]
# 1) How much time did the project work members in total spend on the project work? (change the ```hrs``` variable below to a floating point number representing the number of hours taken e.g. 35.43)

# %%
hrs = None

# %% [markdown]
# 2) Difficulty of each task/question from 1-5 (int or float)

# %%
T1 = None   # Implementing PPO or DDPG for the sanding task (35 points)
T2 = None   # Extending PPO/DDPG to work on the easy and moderate difficulty tasks (45 points)
T3 = None   # Extending PPO/DDPG to work on the difficult task (+20 points)
Q1 = None   # Question 1 How did you extend PPO/DDPG and why? (20 points)

# %% [markdown]
# 3) How well did you understand the content of the task/question from 1-5? (int or float)

# %%
T1 = None   # Implementing PPO or DDPG for the sanding task (35 points)
T2 = None   # Extending PPO/DDPG to work on the easy and moderate difficulty tasks (45 points)
T3 = None   # Extending PPO/DDPG to work on the difficult task (+20 points)
Q1 = None   # Question 1 How did you extend PPO/DDPG and why? (20 points)

# %% [markdown]
# 4) General feedback. Consider questions like:
#
#     - How difficult / time consuming was the project work? What was the most difficult part?
#     - What should be changed in the project work?
#     - What was the most useful / interesting part in the project work?
#
# Please share any additional feedback, suggestions, or comments you have about the lecture, assignment, or course content. Your input is valuable in helping us improve the learning experience.

# %% [markdown]
# DOUBLE CLICK HERE TO EDIT, CLEAR THIS TEXT AND ANSWER HERE
